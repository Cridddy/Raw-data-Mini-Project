# %%
import pandas as pd

# %%
sp500_companies_path = "sp500_companies.csv"
sp500_path = "SP500.csv"
sp500_stocks_path = "sp500_stocks_source.csv"
sp500_constituents_path ="sp500-constituents.csv"
sp500_index_path = "Stocks in the SP 500 Index.csv"
NASDAQ_100_path = "NASDAQ_100.csv"

# %%
sp500_companies = pd.read_csv(sp500_companies_path)
sp500 = pd.read_csv(sp500_path)
sp500_stocks = pd.read_csv(sp500_stocks_path)
sp500_constituents = pd.read_csv(sp500_constituents_path)
sp500_index = pd.read_csv(sp500_index_path)
NASDAQ_100 = pd.read_csv(NASDAQ_100_path)

# %%
#Dependencies

# %%
sp500_companies
# Out:
#     Exchange Symbol                        Shortname  \
# 0        NMS   AAPL                       Apple Inc.
# 1        NMS   MSFT            Microsoft Corporation
# 2        NMS   GOOG                    Alphabet Inc.
# 3        NMS  GOOGL                    Alphabet Inc.
# 4        NMS   AMZN                 Amazon.com, Inc.
# ..       ...    ...                              ...
# 490      NYQ   NCLH  Norwegian Cruise Line Holdings
# 491      NMS    NWL               Newell Brands Inc.
# 492      NYQ    ALK           Alaska Air Group, Inc.
# 493      NYQ    LNC     Lincoln National Corporation
# 494      NYQ   LUMN         Lumen Technologies, Inc.
#
#                                 Longname                  Sector  \
# 0                             Apple Inc.              Technology
# 1                  Microsoft Corporation              Technology
# 2                          Alphabet Inc.  Communication Services
# ...

# %%
sp500
# Out:
#            date       open       high        low      close      volume  \
# 0      19271230    17.6600    17.6600    17.6600    17.6600           0
# 1      19280103    17.7600    17.7600    17.7600    17.7600           0
# 2      19280104    17.7200    17.7200    17.7200    17.7200           0
# 3      19280105    17.5500    17.5500    17.5500    17.5500           0
# 4      19280106    17.6600    17.6600    17.6600    17.6600           0
# ...         ...        ...        ...        ...        ...         ...
# 23878  20230123  3978.1399  4039.3101  3971.6399  4019.8101  3945210000
# 23879  20230124  4001.7400  4023.9199  3989.7900  4016.9500  3320430000
# 23880  20230125  3982.7100  4019.5500  3949.0601  4016.2200  3724020000
# 23881  20230126  4036.0801  4061.5701  4013.2900  4060.4299  3809590000
# 23882  20230127  4053.7200  4094.2100  4048.7000  4070.5601  3907760000
#
#        change_percent   avg_vol_20d
# 0                 NaN           NaN
# ...

# %%
sp500_stocks
# Out:
#                               Date Symbol   Adj Close       Close        High  \
# 0        2010-01-04 00:00:00-05:00    MMM   59.318886   83.019997   83.449997
# 1        2010-01-05 00:00:00-05:00    MMM   58.947342   82.500000   83.230003
# 2        2010-01-06 00:00:00-05:00    MMM   59.783295   83.669998   84.599998
# 3        2010-01-07 00:00:00-05:00    MMM   59.826176   83.730003   83.760002
# 4        2010-01-08 00:00:00-05:00    MMM   60.247749   84.320000   84.320000
# ...                            ...    ...         ...         ...         ...
# 1652350  2023-01-13 00:00:00-05:00    ZTS  160.919998  160.919998  161.399994
# 1652351  2023-01-17 00:00:00-05:00    ZTS  159.570007  159.570007  162.380005
# 1652352  2023-01-18 00:00:00-05:00    ZTS  159.970001  159.970001  162.339996
# 1652353  2023-01-19 00:00:00-05:00    ZTS  161.949997  161.949997  163.160004
# 1652354  2023-01-20 00:00:00-05:00    ZTS  163.809998  163.809998  164.940002
#
# ...

# %%
sp500_constituents
# Out:
#     Ticker                     Name                Industry  \
# 0        A     Agilent Technologies             Health Care
# 1      AAL  American Airlines Group             Industrials
# 2      AAP       Advance Auto Parts  Consumer Discretionary
# 3     AAPL               Apple Inc.  Information Technology
# 4     ABBV                   AbbVie             Health Care
# ..     ...                      ...                     ...
# 498    YUM              Yum! Brands  Consumer Discretionary
# 499    ZBH            Zimmer Biomet             Health Care
# 500   ZBRA       Zebra Technologies  Information Technology
# 501   ZION     Zions Bancorporation              Financials
# 502    ZTS                   Zoetis             Health Care
#
#                                    Sub-Industry    Headquarters Location  \
# 0                         Health Care Equipment  Santa Clara, California
# 1                                      Airlines        Fort Worth, Texas
# ...

# %%
sp500_index
# Out:
#     Symbol                      Description      Category2  Category3  \
# 0     AAPL                        Apple Inc  Common stocks  Large cap
# 1     MSFT                   Microsoft Corp  Common stocks  Large cap
# 2     GOOG             Alphabet Inc Class C  Common stocks  Large cap
# 3    GOOGL             Alphabet Inc Class A  Common stocks  Large cap
# 4     AMZN                  Amazon.Com Inc.  Common stocks  Large cap
# ..     ...                              ...            ...        ...
# 498    LNC            Lincoln National Corp  Common stocks    Mid cap
# 499   LUMN                CenturyLink, Inc.  Common stocks    Mid cap
# 500   TECH                  Bio-Techne Corp  Common stocks    Mid cap
# 501    TAP     Molson Coors Brewing Class B  Common stocks  Small cap
# 502   GEHC  GE HealthCare Technologies Inc.  Common stocks    Unknown
#
#                 GICS Sector          Market cap Dividend yield  \
# ...

# %%
NASDAQ_100
# Out:
#           date        open        high         low       close      volume  \
# 0     19850925    111.1750    111.1750    111.1750    111.1750           0
# 1     19850926    110.6400    110.6400    110.6400    110.6400           0
# 2     19850927    110.6400    110.6400    110.6400    110.6400           0
# 3     19850930    110.6200    110.6200    110.6200    110.6200           0
# 4     19851001    112.1400    112.1400    112.1400    112.1400           0
# ...        ...         ...         ...         ...         ...         ...
# 9403  20230123  11652.0000  11918.8604  11617.8301  11872.5400  5997810000
# 9404  20230124  11802.9502  11889.3701  11780.0703  11846.6396  5670860000
# 9405  20230125  11636.0098  11841.8096  11550.0703  11814.6904  5485570000
# 9406  20230126  11972.5703  12055.8096  11853.3701  12051.4805  5732890000
# 9407  20230127  12000.2100  12248.1504  11999.8701  12166.5996  6243800000
#
#       change_percent   avg_vol_20d
# ...

# %%
#Raw Data Reads

# %%
sp500_companies["Sector"].value_counts()
# Out:
# Technology                71
# Industrials               71
# Financial Services        68
# Healthcare                64
# Consumer Cyclical         57
# Consumer Defensive        36
# Real Estate               31
# Utilities                 30
# Energy                    23
# Communication Services    22
# Basic Materials           22
# Name: Sector, dtype: int64

# %%
sp500_constituents["Industry"].value_counts()
# Out:
# Information Technology    76
# Industrials               70
# Financials                67
# Health Care               64
# Consumer Discretionary    56
# Consumer Staples          33
# Utilities                 30
# Real Estate               30
# Materials                 29
# Communication Services    25
# Energy                    23
# Name: Industry, dtype: int64

# %%
sp500_companies_market_cap_mean = sp500_companies["Marketcap"].mean()
sp500_companies_market_cap_median = sp500_companies["Marketcap"].median()

# %%
sp500_companies_market_cap_mean
# Out:
# 71660874697.1798

# %%
sp500_companies_market_cap_median
# Out:
# 30815211520.0

# %%
top_market_cap_sp500_index = sp500_index.sort_values(by = "Market cap", ascending =False)

# %%
top_market_cap_sp500_index
# Out:
#     Symbol                      Description      Category2  Category3  \
# 80      EL         Estee Lauder Inc Class A  Common stocks  Large cap
# 81    AMAT             Applied Material Inc  Common stocks  Large cap
# 82      CB                        Chubb Ltd  Common stocks  Large cap
# 83      CI                       Cigna Corp  Common stocks  Large cap
# 84     SYK                     Stryker Corp  Common stocks  Large cap
# ..     ...                              ...            ...        ...
# 1     MSFT                   Microsoft Corp  Common stocks  Large cap
# 3    GOOGL             Alphabet Inc Class A  Common stocks  Large cap
# 2     GOOG             Alphabet Inc Class C  Common stocks  Large cap
# 4     AMZN                  Amazon.Com Inc.  Common stocks  Large cap
# 502   GEHC  GE HealthCare Technologies Inc.  Common stocks    Unknown
#
#                 GICS Sector          Market cap Dividend yield  \
# ...

# %%
highest_five_market_cap_sp500_index = top_market_cap_sp500_index.head(5)

# %%
highest_five_market_cap_sp500_index
# Out:
#    Symbol               Description      Category2  Category3  \
# 80     EL  Estee Lauder Inc Class A  Common stocks  Large cap
# 81   AMAT      Applied Material Inc  Common stocks  Large cap
# 82     CB                 Chubb Ltd  Common stocks  Large cap
# 83     CI                Cigna Corp  Common stocks  Large cap
# 84    SYK              Stryker Corp  Common stocks  Large cap
#
#                GICS Sector       Market cap Dividend yield  \
# 80        Consumer Staples  $97,512,218,000          0.90%
# 81  Information Technology  $97,442,979,859          0.88%
# 82              Financials  $95,922,268,824          1.42%
# 83             Health Care  $95,757,456,053          1.43%
# 84             Health Care  $95,519,498,379          1.12%
#
#     Price to TTM earnings  Price to TTM sales  Price to book value   Action
# 80                  29.06                5.38                15.86  Analyze
# 81                  13.72                3.92                 8.01  Analyze
# ...

# %%
low_market_cap_sp500_index = sp500_index.sort_values(by = "Market cap", ascending =True)

# %%
low_market_cap_sp500_index
# Out:
#     Symbol                      Description      Category2  Category3  \
# 502   GEHC  GE HealthCare Technologies Inc.  Common stocks    Unknown
# 4     AMZN                  Amazon.Com Inc.  Common stocks  Large cap
# 2     GOOG             Alphabet Inc Class C  Common stocks  Large cap
# 3    GOOGL             Alphabet Inc Class A  Common stocks  Large cap
# 1     MSFT                   Microsoft Corp  Common stocks  Large cap
# ..     ...                              ...            ...        ...
# 84     SYK                     Stryker Corp  Common stocks  Large cap
# 83      CI                       Cigna Corp  Common stocks  Large cap
# 82      CB                        Chubb Ltd  Common stocks  Large cap
# 81    AMAT             Applied Material Inc  Common stocks  Large cap
# 80      EL         Estee Lauder Inc Class A  Common stocks  Large cap
#
#                 GICS Sector          Market cap Dividend yield  \
# ...

# %%
lowest_five_market_cap_sp500_index = low_market_cap_sp500_index.head(5)

# %%
lowest_five_market_cap_sp500_index
# Out:
#     Symbol                      Description      Category2  Category3  \
# 502   GEHC  GE HealthCare Technologies Inc.  Common stocks    Unknown
# 4     AMZN                  Amazon.Com Inc.  Common stocks  Large cap
# 2     GOOG             Alphabet Inc Class C  Common stocks  Large cap
# 3    GOOGL             Alphabet Inc Class A  Common stocks  Large cap
# 1     MSFT                   Microsoft Corp  Common stocks  Large cap
#
#                 GICS Sector          Market cap Dividend yield  \
# 502             Health Care                  $0          0.00%
# 4    Consumer Discretionary  $1,012,208,127,343          0.00%
# 2    Communication Services  $1,185,974,720,000          0.00%
# 3    Communication Services  $1,185,974,720,000          0.00%
# 1    Information Technology  $1,846,063,276,184          1.02%
#
#      Price to TTM earnings  Price to TTM sales  Price to book value   Action
# 502                   0.00                0.00                 0.00  Analyze
# ...

# %%
sp500_cap_space = sp500_index["Category3"].value_counts()

# %%
sp500_cap_space
# Out:
# Large cap    467
# Mid cap       34
# Small cap      1
# Unknown        1
# Name: Category3, dtype: int64

# %%
top_dividend_yield_sp500_index = sp500_index.sort_values(by = "Dividend yield", ascending =False)

# %%
top_five_dividend_yield_sp500 = top_dividend_yield_sp500_index.head(5)

# %%
top_five_dividend_yield_sp500
# Out:
#     Symbol                 Description      Category2  Category3  \
# 99      MO            Altria Group Inc  Common stocks  Large cap
# 54       T                   AT&T Inc.  Common stocks  Large cap
# 448    VFC                     VF Corp  Common stocks  Large cap
# 40      VZ  Verizon Communications Inc  Common stocks  Large cap
# 193    KMI           Kinder Morgan Inc  Common stocks  Large cap
#
#                 GICS Sector        Market cap Dividend yield  \
# 99         Consumer Staples   $79,375,325,251          8.06%
# 54   Communication Services  $142,600,000,000          6.81%
# 448  Consumer Discretionary   $11,618,125,942          6.58%
# 40   Communication Services  $169,126,648,591          6.27%
# 193                  Energy   $41,830,479,941          5.79%
#
#      Price to TTM earnings  Price to TTM sales  Price to book value   Action
# 99                   26.40                3.77               -45.10  Analyze
# ...

# %%
bottom_dividend_yield_sp500_index = sp500_index.sort_values(by = "Dividend yield", ascending =True)

# %%
bottom_five_dividend_yield_sp500 = bottom_dividend_yield_sp500_index.head(5)

# %%
bottom_five_dividend_yield_sp500
# Out:
#     Symbol                      Description      Category2  Category3  \
# 502   GEHC  GE HealthCare Technologies Inc.  Common stocks    Unknown
# 260    URI               United Rentals Inc  Common stocks  Large cap
# 95    VRTX       Vertex Pharmaceuticals Inc  Common stocks  Large cap
# 263   APTV                        Aptiv Plc  Common stocks  Large cap
# 270   ENPH               Enphase Energy Inc  Common stocks  Large cap
#
#                 GICS Sector       Market cap Dividend yield  \
# 502             Health Care               $0          0.00%
# 260             Industrials  $29,905,223,382          0.00%
# 95              Health Care  $82,403,089,921          0.00%
# 263  Consumer Discretionary  $28,937,415,037          0.00%
# 270  Information Technology  $28,274,821,447          0.00%
#
#      Price to TTM earnings  Price to TTM sales  Price to book value   Action
# 502                   0.00                0.00                 0.00  Analyze
# ...

# %%
# Technology Sector Data

# %%
sp500_technology = sp500_companies.loc[sp500_companies["Sector"] =="Technology", :]

# %%
sp500_technology_top_marketcap = sp500_technology.sort_values(by = "Marketcap", ascending=False)  
sp500_technology_top_5_marketcap = sp500_technology_top_marketcap.head(5)

# %%
sp500_technology_top_5_marketcap
# Out:
#    Exchange Symbol              Shortname               Longname      Sector  \
# 0       NMS   AAPL             Apple Inc.             Apple Inc.  Technology
# 1       NMS   MSFT  Microsoft Corporation  Microsoft Corporation  Technology
# 8       NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation  Technology
# 22      NMS   AVGO          Broadcom Inc.          Broadcom Inc.  Technology
# 25      NYQ   ORCL     Oracle Corporation     Oracle Corporation  Technology
#
#                    Industry  Currentprice      Marketcap        Ebitda  \
# 0      Consumer Electronics        137.87  2183336820736  1.305410e+11
# 1   Software—Infrastructure        240.22  1803566972928  9.798300e+10
# 8            Semiconductors        178.39   444547891200  1.068000e+10
# 22           Semiconductors        570.78   238520991744  1.927000e+10
# 25  Software—Infrastructure         87.25   232996749312  1.840500e+10
#
#     Revenuegrowth         City State        Country  Fulltimeemployees  \
# ...

# %%
sp500_technology_bottom_marketcap = sp500_technology.sort_values(by = "Marketcap", ascending=True)    
sp500_technology_bottom_5_marketcap = sp500_technology_bottom_marketcap.head(5)

# %%
sp500_technology_bottom_5_marketcap
# Out:
#     Exchange Symbol                  Shortname                   Longname  \
# 489      NYQ    DXC     DXC Technology Company     DXC Technology Company
# 477      NMS   FTNT             Fortinet, Inc.             Fortinet, Inc.
# 468      NMS   FFIV                   F5, Inc.                   F5, Inc.
# 459      NYQ   JNPR     Juniper Networks, Inc.     Juniper Networks, Inc.
# 452      NYQ   CDAY  Ceridian HCM Holding Inc.  Ceridian HCM Holding Inc.
#
#          Sector                         Industry  Currentprice    Marketcap  \
# 489  Technology  Information Technology Services         28.40   6533845504
# 477  Technology          Software—Infrastructure         49.27   8055645184
# 468  Technology          Software—Infrastructure        144.65   8856832000
# 459  Technology          Communication Equipment         31.46  10230194176
# 452  Technology             Software—Application         69.75  10713251840
#
# ...

# %%
sp500_technology_top_currentprice = sp500_technology.sort_values(by = "Currentprice", ascending=False)    
sp500_technology_top_5_currentprice = sp500_technology_top_currentprice.head(5)

# %%
sp500_technology_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 22       NMS   AVGO                    Broadcom Inc.
# 116      NMS   LRCX         Lam Research Corporation
# 88       NYQ    NOW                 ServiceNow, Inc.
# 128      NMS   KLAC                  KLA Corporation
# 336      NYQ    TDY  Teledyne Technologies Incorpora
#
#                                Longname      Sector  \
# 22                        Broadcom Inc.  Technology
# 116            Lam Research Corporation  Technology
# 88                     ServiceNow, Inc.  Technology
# 128                     KLA Corporation  Technology
# 336  Teledyne Technologies Incorporated  Technology
#
#                                 Industry  Currentprice     Marketcap  \
# 22                        Semiconductors        570.78  238520991744
# 116  Semiconductor Equipment & Materials        472.50   66527531008
# 88                  Software—Application        441.83   87924170752
# ...

# %%
sp500_technology_bottom_currentprice = sp500_technology.sort_values(by = "Currentprice", ascending=True)  
sp500_technology_bottom_5_currentprice = sp500_technology_bottom_currentprice.head(5)

# %%
sp500_technology_bottom_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 316      NYQ    HPE  Hewlett Packard Enterprise Comp
# 253      NYQ    HPQ                          HP Inc.
# 489      NYQ    DXC           DXC Technology Company
# 63       NMS   INTC                Intel Corporation
# 459      NYQ   JNPR           Juniper Networks, Inc.
#
#                                Longname      Sector  \
# 316  Hewlett Packard Enterprise Company  Technology
# 253                             HP Inc.  Technology
# 489              DXC Technology Company  Technology
# 63                    Intel Corporation  Technology
# 459              Juniper Networks, Inc.  Technology
#
#                             Industry  Currentprice     Marketcap  \
# 316          Communication Equipment         15.95   20630368256
# 253                Computer Hardware         27.91   30218715136
# 489  Information Technology Services         28.40    6533845504
# ...

# %%
sp500_technology_top_ebitda = sp500_technology.sort_values(by = "Ebitda", ascending=False)  
sp500_technology_top_5_ebitda = sp500_technology_top_ebitda.head(5)

# %%
sp500_technology_top_5_ebitda
# Out:
#    Exchange Symbol              Shortname               Longname      Sector  \
# 0       NMS   AAPL             Apple Inc.             Apple Inc.  Technology
# 1       NMS   MSFT  Microsoft Corporation  Microsoft Corporation  Technology
# 63      NMS   INTC      Intel Corporation      Intel Corporation  Technology
# 22      NMS   AVGO          Broadcom Inc.          Broadcom Inc.  Technology
# 25      NYQ   ORCL     Oracle Corporation     Oracle Corporation  Technology
#
#                    Industry  Currentprice      Marketcap        Ebitda  \
# 0      Consumer Electronics        137.87  2183336820736  1.305410e+11
# 1   Software—Infrastructure        240.22  1803566972928  9.798300e+10
# 63           Semiconductors         29.22   118837739520  2.533300e+10
# 22           Semiconductors        570.78   238520991744  1.927000e+10
# 25  Software—Infrastructure         87.25   232996749312  1.840500e+10
#
#     Revenuegrowth         City State        Country  Fulltimeemployees  \
# ...

# %%
sp500_technology_bottom_ebitda = sp500_technology.sort_values(by = "Ebitda", ascending=True)  
sp500_technology_bottom_5_ebitda = sp500_technology_bottom_ebitda.head(5)

# %%
sp500_technology_bottom_5_ebitda
# Out:
#     Exchange Symbol                     Shortname  \
# 452      NYQ   CDAY     Ceridian HCM Holding Inc.
# 390      NMS   SEDG  SolarEdge Technologies, Inc.
# 338      NYQ   PAYC         Paycom Software, Inc.
# 422      NYQ    TYL      Tyler Technologies, Inc.
# 351      NMS   FSLR             First Solar, Inc.
#
#                          Longname      Sector              Industry  \
# 452     Ceridian HCM Holding Inc.  Technology  Software—Application
# 390  SolarEdge Technologies, Inc.  Technology                 Solar
# 338         Paycom Software, Inc.  Technology  Software—Application
# 422      Tyler Technologies, Inc.  Technology  Software—Application
# 351             First Solar, Inc.  Technology                 Solar
#
#      Currentprice    Marketcap       Ebitda  Revenuegrowth           City  \
# 452         69.75  10713251840   41500000.0          0.227    Minneapolis
# 390        294.73  15479072768  242948992.0          0.516       Herzliya
# ...

# %%
sp500_technology_top_revenuegrowth = sp500_technology.sort_values(by = "Revenuegrowth", ascending=False)  
sp500_technology_top_5_revenuegrowth = sp500_technology_top_revenuegrowth.head(5)

# %%
sp500_technology_top_5_revenuegrowth
# Out:
#     Exchange Symbol                       Shortname  \
# 251      NGM   ENPH            Enphase Energy, Inc.
# 219      NYQ   ANET           Arista Networks, Inc.
# 342      NMS   MPWR  Monolithic Power Systems, Inc.
# 390      NMS   SEDG    SolarEdge Technologies, Inc.
# 91       NMS    ADI            Analog Devices, Inc.
#
#                            Longname      Sector           Industry  \
# 251            Enphase Energy, Inc.  Technology              Solar
# 219           Arista Networks, Inc.  Technology  Computer Hardware
# 342  Monolithic Power Systems, Inc.  Technology     Semiconductors
# 390    SolarEdge Technologies, Inc.  Technology              Solar
# 91             Analog Devices, Inc.  Technology     Semiconductors
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth         City  \
# 251        222.54  30248525824  4.023030e+08          0.806      Fremont
# 219        115.13  35379449856  1.381614e+09          0.572  Santa Clara
# ...

# %%
sp500_technology_bottom_revenuegrowth = sp500_technology.sort_values(by = "Revenuegrowth", ascending=True)  
sp500_technology_bottom_5_revenuegrowth = sp500_technology_bottom_revenuegrowth.head(5)

# %%
sp500_technology_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 419      NMS    STX  Seagate Technology Holdings PLC
# 63       NMS   INTC                Intel Corporation
# 117      NMS     MU          Micron Technology, Inc.
# 386      NMS    TER                   Teradyne, Inc.
# 489      NYQ    DXC           DXC Technology Company
#
#                             Longname      Sector  \
# 419  Seagate Technology Holdings plc  Technology
# 63                 Intel Corporation  Technology
# 117          Micron Technology, Inc.  Technology
# 386                   Teradyne, Inc.  Technology
# 489           DXC Technology Company  Technology
#
#                                 Industry  Currentprice     Marketcap  \
# 419                    Computer Hardware         59.34   13211219968
# 63                        Semiconductors         29.22  118837739520
# 117                       Semiconductors         58.46   65485135872
# ...

# %%
# Industrials Sector

# %%
sp500_industrial = sp500_companies.loc[sp500_companies["Sector"] =="Industrials", :]

# %%
sp500_industrial_top_marketcap = sp500_industrial.sort_values(by = "Marketcap", ascending=False)    
sp500_industrial_top_5_marketcap= sp500_industrial_top_marketcap.head(5)

# %%
sp500_industrial_top_5_marketcap
# Out:
#    Exchange Symbol                        Shortname  \
# 45      NYQ    UPS      United Parcel Service, Inc.
# 50      NYQ    RTX  Raytheon Technologies Corporati
# 52      NMS    HON     Honeywell International Inc.
# 56      NYQ    UNP        Union Pacific Corporation
# 58      NYQ    CAT                Caterpillar, Inc.
#
#                              Longname       Sector  \
# 45        United Parcel Service, Inc.  Industrials
# 50  Raytheon Technologies Corporation  Industrials
# 52       Honeywell International Inc.  Industrials
# 56          Union Pacific Corporation  Industrials
# 58                   Caterpillar Inc.  Industrials
#
#                                Industry  Currentprice     Marketcap  \
# 45       Integrated Freight & Logistics        178.13  154820263936
# 50                  Aerospace & Defense         94.36  141236158464
# 52                        Conglomerates        202.03  139082088448
# ...

# %%
sp500_industrial_bottom_marketcap = sp500_industrial.sort_values(by = "Marketcap", ascending=True)    
sp500_industrial_bottom_5_marketcap= sp500_industrial_bottom_marketcap.head(5)

# %%
sp500_industrial_bottom_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 492      NYQ    ALK           Alaska Air Group, Inc.
# 487      NYQ   GNRC           Generac Holdlings Inc.
# 476      NYQ    PNR                     Pentair plc.
# 473      NYQ    RHI   Robert Half International Inc.
# 471      NYQ    HII  Huntington Ingalls Industries,
#
#                                 Longname       Sector  \
# 492               Alaska Air Group, Inc.  Industrials
# 487                Generac Holdings Inc.  Industrials
# 476                          Pentair plc  Industrials
# 473       Robert Half International Inc.  Industrials
# 471  Huntington Ingalls Industries, Inc.  Industrials
#
#                            Industry  Currentprice   Marketcap        Ebitda  \
# 492                        Airlines         49.82  6319069184  1.092000e+09
# 487  Specialty Industrial Machinery        108.49  6844634112  8.662360e+08
# 476  Specialty Industrial Machinery         49.16  8134898688  7.621000e+08
# ...

# %%
sp500_industrial_top_currentprice = sp500_industrial.sort_values(by = "Currentprice", ascending=False)    
sp500_industrial_top_5_currentprice = sp500_industrial_top_currentprice.head(5)

# %%
sp500_industrial_top_5_currentprice
# Out:
#     Exchange Symbol                     Shortname  \
# 210      NYQ    TDG  Transdigm Group Incorporated
# 258      NYQ    GWW           W.W. Grainger, Inc.
# 107      NYQ    NOC  Northrop Grumman Corporation
# 61       NYQ    LMT   Lockheed Martin Corporation
# 160      NYQ    ROP      Roper Technologies, Inc.
#
#                          Longname       Sector  \
# 210  TransDigm Group Incorporated  Industrials
# 258           W.W. Grainger, Inc.  Industrials
# 107  Northrop Grumman Corporation  Industrials
# 61    Lockheed Martin Corporation  Industrials
# 160      Roper Technologies, Inc.  Industrials
#
#                            Industry  Currentprice     Marketcap        Ebitda  \
# 210             Aerospace & Defense        672.65   37163175936  2.368000e+09
# 258         Industrial Distribution        560.24   28863563776  2.145000e+09
# 107             Aerospace & Defense        450.76   70921674752  8.757000e+09
# ...

# %%
sp500_industrial_bottom_currentprice = sp500_industrial.sort_values(by = "Currentprice", ascending=True)    
sp500_industrial_bottom_5_currentprice = sp500_industrial_bottom_currentprice.head(5)

# %%
sp500_industrial_bottom_5_currentprice
# Out:
#     Exchange Symbol                      Shortname  \
# 454      NMS    AAL  American Airlines Group, Inc.
# 112      NMS    CSX                CSX Corporation
# 306      NYQ    LUV     Southwest Airlines Company
# 375      NYQ    HWM          Howmet Aerospace Inc.
# 280      NYQ    DAL          Delta Air Lines, Inc.
#
#                          Longname       Sector             Industry  \
# 454  American Airlines Group Inc.  Industrials             Airlines
# 112               CSX Corporation  Industrials            Railroads
# 306        Southwest Airlines Co.  Industrials             Airlines
# 375         Howmet Aerospace Inc.  Industrials  Aerospace & Defense
# 280         Delta Air Lines, Inc.  Industrials             Airlines
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth          City  \
# 454         16.34  10619382784  2.400000e+09          0.501    Fort Worth
# 112         32.01  67298140160  7.273000e+09          0.183  Jacksonville
# ...

# %%
sp500_industrial_top_ebitda = sp500_industrial.sort_values(by = "Ebitda", ascending=False)  
sp500_industrial_top_5_ebitda = sp500_industrial_top_ebitda.head(5)

# %%
sp500_industrial_top_5_ebitda
# Out:
#    Exchange Symbol                        Shortname  \
# 45      NYQ    UPS      United Parcel Service, Inc.
# 56      NYQ    UNP        Union Pacific Corporation
# 50      NYQ    RTX  Raytheon Technologies Corporati
# 58      NYQ    CAT                Caterpillar, Inc.
# 62      NYQ     DE                  Deere & Company
#
#                              Longname       Sector  \
# 45        United Parcel Service, Inc.  Industrials
# 56          Union Pacific Corporation  Industrials
# 50  Raytheon Technologies Corporation  Industrials
# 58                   Caterpillar Inc.  Industrials
# 62                    Deere & Company  Industrials
#
#                                Industry  Currentprice     Marketcap  \
# 45       Integrated Freight & Logistics        178.13  154820263936
# 56                            Railroads        208.66  134142517248
# 50                  Aerospace & Defense         94.36  141236158464
# ...

# %%
sp500_industrial_bottom_ebitda = sp500_industrial.sort_values(by = "Ebitda", ascending=True)   
sp500_industrial_bottom_5_ebitda = sp500_industrial_bottom_ebitda.head(5)

# %%
sp500_industrial_bottom_5_ebitda
# Out:
#     Exchange Symbol               Shortname                 Longname  \
# 60       NYQ     BA    Boeing Company (The)       The Boeing Company
# 461      NYQ   ALLE            Allegion plc             Allegion plc
# 465      NYQ    AOS  A.O. Smith Corporation  A. O. Smith Corporation
# 412      NMS   NDSN     Nordson Corporation      Nordson Corporation
# 476      NYQ    PNR            Pentair plc.              Pentair plc
#
#           Sector                        Industry  Currentprice     Marketcap  \
# 60   Industrials             Aerospace & Defense        206.76  123225440256
# 461  Industrials  Security & Protection Services        111.30    9777126400
# 465  Industrials  Specialty Industrial Machinery         59.15    9036700672
# 412  Industrials  Specialty Industrial Machinery        233.82   13602852864
# 476  Industrials  Specialty Industrial Machinery         49.16    8134898688
#
#            Ebitda  Revenuegrowth       City State         Country  \
# ...

# %%
sp500_industrial_top_revenuegrowth = sp500_industrial.sort_values(by = "Revenuegrowth", ascending=False)   
sp500_industrial_top_5_revenuegrowth = sp500_industrial_top_revenuegrowth.head(5)

# %%
sp500_industrial_top_5_revenuegrowth
# Out:
#     Exchange Symbol                       Shortname  \
# 306      NYQ    LUV      Southwest Airlines Company
# 384      NMS    UAL  United Airlines Holdings, Inc.
# 454      NMS    AAL   American Airlines Group, Inc.
# 492      NYQ    ALK          Alaska Air Group, Inc.
# 280      NYQ    DAL           Delta Air Lines, Inc.
#
#                            Longname       Sector  Industry  Currentprice  \
# 306          Southwest Airlines Co.  Industrials  Airlines         37.06
# 384  United Airlines Holdings, Inc.  Industrials  Airlines         49.46
# 454    American Airlines Group Inc.  Industrials  Airlines         16.34
# 492          Alaska Air Group, Inc.  Industrials  Airlines         49.82
# 280           Delta Air Lines, Inc.  Industrials  Airlines         39.03
#
#        Marketcap        Ebitda  Revenuegrowth        City State  \
# 306  21936556032  2.346000e+09          0.679      Dallas    TX
# 384  16015494144  3.089000e+09          0.662     Chicago    IL
# ...

# %%
sp500_industrial_bottom_revenuegrowth = sp500_industrial.sort_values(by = "Revenuegrowth", ascending=True)  
sp500_industrial_bottom_5_revenuegrowth = sp500_industrial_bottom_revenuegrowth.head(5)

# %%
sp500_industrial_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                      Shortname  \
# 207      NYQ    LHX    L3Harris Technologies, Inc.
# 160      NYQ    ROP       Roper Technologies, Inc.
# 223      NYQ   OTIS     Otis Worldwide Corporation
# 465      NYQ    AOS         A.O. Smith Corporation
# 449      NMS   CHRW  C.H. Robinson Worldwide, Inc.
#
#                           Longname       Sector  \
# 207    L3Harris Technologies, Inc.  Industrials
# 160       Roper Technologies, Inc.  Industrials
# 223     Otis Worldwide Corporation  Industrials
# 465        A. O. Smith Corporation  Industrials
# 449  C.H. Robinson Worldwide, Inc.  Industrials
#
#                            Industry  Currentprice    Marketcap        Ebitda  \
# 207             Aerospace & Defense        192.51  37775273984  3.517000e+09
# 160  Specialty Industrial Machinery        441.59  46581121024  2.348600e+09
# 223  Specialty Industrial Machinery         80.81  34325581824  2.320000e+09
# ...

# %%
# Financial Services

# %%
sp500_fs = sp500_companies.loc[sp500_companies["Sector"] =="Financial Services", :]

# %%
sp500_fs_top_marketcap = sp500_fs.sort_values(by = "Marketcap", ascending=False)    
sp500_fs_top_5_marketcap = sp500_fs_top_marketcap.head(5)

# %%
sp500_fs_top_5_marketcap
# Out:
#    Exchange Symbol                    Shortname                     Longname  \
# 5       NYQ  BRK-B  Berkshire Hathaway Inc. New      Berkshire Hathaway Inc.
# 10      NYQ    JPM        JP Morgan Chase & Co.         JPMorgan Chase & Co.
# 12      NYQ     MA      Mastercard Incorporated      Mastercard Incorporated
# 18      NYQ    BAC  Bank of America Corporation  Bank of America Corporation
# 35      NYQ    WFC        Wells Fargo & Company        Wells Fargo & Company
#
#                 Sector               Industry  Currentprice     Marketcap  \
# 5   Financial Services  Insurance—Diversified        309.87  683734335488
# 10  Financial Services      Banks—Diversified        135.08  409068175360
# 12  Financial Services        Credit Services        376.28  369716559872
# 18  Financial Services      Banks—Diversified         33.85  270690992128
# 35  Financial Services      Banks—Diversified         43.92  175119138816
#
# ...

# %%
sp500_fs_bottom_marketcap = sp500_fs.sort_values(by = "Marketcap", ascending=True)  
sp500_fs_bottom_5_marketcap = sp500_fs_bottom_marketcap.head(5)

# %%
sp500_fs_bottom_5_marketcap
# Out:
#     Exchange Symbol                     Shortname  \
# 493      NYQ    LNC  Lincoln National Corporation
# 488      NYQ    AIZ                Assurant, Inc.
# 484      NMS   SBNY                Signature Bank
# 478      NMS   ZION     Zions Bancorporation N.A.
# 469      NYQ    IVZ                   Invesco Ltd
#
#                                        Longname              Sector  \
# 493                Lincoln National Corporation  Financial Services
# 488                              Assurant, Inc.  Financial Services
# 484                              Signature Bank  Financial Services
# 478  Zions Bancorporation, National Association  Financial Services
# 469                                Invesco Ltd.  Financial Services
#
#                 Industry  Currentprice   Marketcap        Ebitda  \
# 493       Insurance—Life         31.75  5737510400  1.422000e+09
# 488  Insurance—Specialty        128.91  6810496000  7.198000e+08
# ...

# %%
sp500_fs_top_currentprice = sp500_fs.sort_values(by = "Currentprice", ascending=False) 
sp500_fs_top_5_currentprice = sp500_fs_top_currentprice.head(5)

# %%
sp500_fs_top_5_currentprice
# Out:
#     Exchange Symbol                      Shortname  \
# 70       NYQ    BLK                BlackRock, Inc.
# 186      NYQ   MSCI                       MSCI Inc
# 383      NYQ    FDS  FactSet Research Systems Inc.
# 12       NYQ     MA        Mastercard Incorporated
# 87       NYQ   SPGI                S&P Global Inc.
#
#                           Longname              Sector  \
# 70                 BlackRock, Inc.  Financial Services
# 186                      MSCI Inc.  Financial Services
# 383  FactSet Research Systems Inc.  Financial Services
# 12         Mastercard Incorporated  Financial Services
# 87                 S&P Global Inc.  Financial Services
#
#                              Industry  Currentprice     Marketcap  \
# 70                   Asset Management        741.71  111075524608
# 186  Financial Data & Stock Exchanges        511.76   42192924672
# 383  Financial Data & Stock Exchanges        423.76   16016942080
# ...

# %%
sp500_fs_bottom_currentprice = sp500_fs.sort_values(by = "Currentprice", ascending=True) 
sp500_fs_bottom_5_currentprice = sp500_fs_bottom_currentprice.head(5)

# %%
sp500_fs_bottom_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 313      NMS   HBAN  Huntington Bancshares Incorpora
# 378      NYQ    KEY                          KeyCorp
# 469      NYQ    IVZ                      Invesco Ltd
# 309      NYQ     RF    Regions Financial Corporation
# 393      NYQ    BEN         Franklin Resources, Inc.
#
#                                Longname              Sector          Industry  \
# 313  Huntington Bancshares Incorporated  Financial Services    Banks—Regional
# 378                             KeyCorp  Financial Services    Banks—Regional
# 469                        Invesco Ltd.  Financial Services  Asset Management
# 309       Regions Financial Corporation  Financial Services    Banks—Regional
# 393            Franklin Resources, Inc.  Financial Services  Asset Management
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth        City State  \
# 313         14.11  20805758976           NaN          0.023    Columbus    OH
# ...

# %%
sp500_fs_top_ebitda = sp500_fs.sort_values(by = "Ebitda", ascending=False)
sp500_fs_top_5_ebitda = sp500_fs_top_ebitda.head(5)

# %%
sp500_fs_top_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 164      NYQ    AIG  American International Group, I
# 5        NYQ  BRK-B      Berkshire Hathaway Inc. New
# 83       NYQ     CB                    Chubb Limited
# 70       NYQ    BLK                  BlackRock, Inc.
# 89       NYQ    MMC  Marsh & McLennan Companies, Inc
#
#                                Longname              Sector  \
# 164  American International Group, Inc.  Financial Services
# 5               Berkshire Hathaway Inc.  Financial Services
# 83                        Chubb Limited  Financial Services
# 70                      BlackRock, Inc.  Financial Services
# 89     Marsh & McLennan Companies, Inc.  Financial Services
#
#                           Industry  Currentprice     Marketcap        Ebitda  \
# 164          Insurance—Diversified         62.47   46413959168  2.355100e+10
# 5            Insurance—Diversified        309.87  683734335488  9.947000e+09
# ...

# %%
sp500_fs_bottom_ebitda = sp500_fs.sort_values(by = "Ebitda", ascending=True) 
sp500_fs_bottom_5_ebitda = sp500_fs_bottom_ebitda.head(5)

# %%
sp500_fs_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 379      NMS   CINF  Cincinnati Financial Corporatio
# 425      NMS   MKTX       MarketAxess Holdings, Inc.
# 383      NYQ    FDS    FactSet Research Systems Inc.
# 488      NYQ    AIZ                   Assurant, Inc.
# 439      NYQ     GL                  Globe Life Inc.
#
#                              Longname              Sector  \
# 379  Cincinnati Financial Corporation  Financial Services
# 425         MarketAxess Holdings Inc.  Financial Services
# 383     FactSet Research Systems Inc.  Financial Services
# 488                    Assurant, Inc.  Financial Services
# 439                   Globe Life Inc.  Financial Services
#
#                              Industry  Currentprice    Marketcap       Ebitda  \
# 379     Insurance—Property & Casualty        102.73  16147513344   25000000.0
# 425                   Capital Markets        335.98  12776143872  375836000.0
# ...

# %%
sp500_fs_top_revenuegrowth = sp500_fs.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_fs_top_5_revenuegrowth = sp500_fs_top_revenuegrowth.head(5)

# %%
sp500_fs_top_5_revenuegrowth
# Out:
#     Exchange Symbol                      Shortname  \
# 295      NMS    PFG  Principal Financial Group Inc
# 87       NYQ   SPGI                S&P Global Inc.
# 327      NYQ    MTB           M&T Bank Corporation
# 261      NYQ    DFS    Discover Financial Services
# 484      NMS   SBNY                 Signature Bank
#
#                             Longname              Sector  \
# 295  Principal Financial Group, Inc.  Financial Services
# 87                   S&P Global Inc.  Financial Services
# 327             M&T Bank Corporation  Financial Services
# 261      Discover Financial Services  Financial Services
# 484                   Signature Bank  Financial Services
#
#                              Industry  Currentprice    Marketcap  \
# 295                  Asset Management         87.96  23315468288
# 87   Financial Data & Stock Exchanges        368.05  88700043264
# 327                    Banks—Regional        153.69  19777597440
# ...

# %%
sp500_fs_bottom_revenuegrowth = sp500_fs.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_fs_bottom_5_revenuegrowth = sp500_fs_bottom_revenuegrowth.head(5)

# %%
sp500_fs_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 270      NMS   TROW        T. Rowe Price Group, Inc.
# 379      NMS   CINF  Cincinnati Financial Corporatio
# 331      NYQ    SYF              Synchrony Financial
# 209      NYQ    PRU       Prudential Financial, Inc.
# 469      NYQ    IVZ                      Invesco Ltd
#
#                              Longname              Sector  \
# 270         T. Rowe Price Group, Inc.  Financial Services
# 379  Cincinnati Financial Corporation  Financial Services
# 331               Synchrony Financial  Financial Services
# 209        Prudential Financial, Inc.  Financial Services
# 469                      Invesco Ltd.  Financial Services
#
#                           Industry  Currentprice    Marketcap        Ebitda  \
# 270               Asset Management        117.81  27001815040  3.662900e+09
# 379  Insurance—Property & Casualty        102.73  16147513344  2.500000e+07
# ...

# %%
# Healthcare Sector

# %%
sp500_hc = sp500_companies.loc[sp500_companies["Sector"] =="Healthcare", :]

# %%
sp500_hc_top_marketcap = sp500_hc.sort_values(by = "Marketcap", ascending=False) 
sp500_hc_top_5_marketcap = sp500_hc_top_marketcap.head(5)

# %%
sp500_hc_top_5_marketcap
# Out:
#    Exchange Symbol                        Shortname  \
# 7       NYQ    UNH  UnitedHealth Group Incorporated
# 9       NYQ    JNJ                Johnson & Johnson
# 16      NYQ    LLY            Eli Lilly and Company
# 17      NYQ    MRK            Merck & Company, Inc.
# 19      NYQ   ABBV                      AbbVie Inc.
#
#                            Longname      Sector                    Industry  \
# 7   UnitedHealth Group Incorporated  Healthcare            Healthcare Plans
# 9                 Johnson & Johnson  Healthcare  Drug Manufacturers—General
# 16            Eli Lilly and Company  Healthcare  Drug Manufacturers—General
# 17                Merck & Co., Inc.  Healthcare  Drug Manufacturers—General
# 19                      AbbVie Inc.  Healthcare  Drug Manufacturers—General
#
#     Currentprice     Marketcap        Ebitda  Revenuegrowth           City  \
# 7         486.72  458417733632  2.935100e+10          0.118     Minnetonka
# ...

# %%
sp500_hc_bottom_marketcap = sp500_hc.sort_values(by = "Marketcap", ascending=True) 
sp500_hc_bottom_5_marketcap = sp500_hc_bottom_marketcap.head(5)

# %%
sp500_hc_bottom_5_marketcap
# Out:
#     Exchange Symbol              Shortname               Longname      Sector  \
# 486      NYQ    DVA            DaVita Inc.            DaVita Inc.  Healthcare
# 481      NMS   XRAY   DENTSPLY SIRONA Inc.   DENTSPLY SIRONA Inc.  Healthcare
# 480      NYQ    OGN          Organon & Co.          Organon & Co.  Healthcare
# 467      NYQ   CTLT         Catalent, Inc.         Catalent, Inc.  Healthcare
# 447      NYQ    TFX  Teleflex Incorporated  Teleflex Incorporated  Healthcare
#
#                                    Industry  Currentprice    Marketcap  \
# 486                 Medical Care Facilities         80.32   7236831744
# 481          Medical Instruments & Supplies         36.97   7945296896
# 480              Drug Manufacturers—General         31.34   7946256896
# 467  Drug Manufacturers—Specialty & Generic         49.45   8899219456
# 447          Medical Instruments & Supplies        235.69  11040898048
#
#            Ebitda  Revenuegrowth         City State        Country  \
# ...

# %%
sp500_hc_top_currentprice = sp500_hc.sort_values(by = "Currentprice", ascending=False) 
sp500_hc_top_5_currentprice= sp500_hc_top_currentprice.head(5)

# %%
sp500_hc_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 216      NYQ    MTD  Mettler-Toledo International, I
# 100      NMS   REGN  Regeneron Pharmaceuticals, Inc.
# 24       NYQ    TMO     Thermo Fisher Scientific Inc
# 124      NYQ    HUM                      Humana Inc.
# 190      NMS   IDXX         IDEXX Laboratories, Inc.
#
#                               Longname      Sector                Industry  \
# 216  Mettler-Toledo International Inc.  Healthcare  Diagnostics & Research
# 100    Regeneron Pharmaceuticals, Inc.  Healthcare           Biotechnology
# 24       Thermo Fisher Scientific Inc.  Healthcare  Diagnostics & Research
# 124                        Humana Inc.  Healthcare        Healthcare Plans
# 190           IDEXX Laboratories, Inc.  Healthcare  Diagnostics & Research
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth        City  \
# 216       1561.53   35892858880  1.139487e+09          0.058    Columbus
# ...

# %%
sp500_hc_bottom_currentprice = sp500_hc.sort_values(by = "Currentprice", ascending=True) 
sp500_hc_bottom_5_currentprice = sp500_hc_bottom_currentprice.head(5)

# %%
sp500_hc_bottom_5_currentprice
# Out:
#     Exchange Symbol                       Shortname  \
# 406      NMS   VTRS                    Viatris Inc.
# 480      NYQ    OGN                   Organon & Co.
# 246      NMS    WBA  Walgreens Boots Alliance, Inc.
# 481      NMS   XRAY            DENTSPLY SIRONA Inc.
# 303      NYQ    BAX       Baxter International Inc.
#
#                            Longname      Sector  \
# 406                    Viatris Inc.  Healthcare
# 480                   Organon & Co.  Healthcare
# 246  Walgreens Boots Alliance, Inc.  Healthcare
# 481            DENTSPLY SIRONA Inc.  Healthcare
# 303       Baxter International Inc.  Healthcare
#
#                                    Industry  Currentprice    Marketcap  \
# 406  Drug Manufacturers—Specialty & Generic         11.60  14028923904
# 480              Drug Manufacturers—General         31.34   7946256896
# 246                Pharmaceutical Retailers         35.88  30998347776
# ...

# %%
sp500_hc_top_ebitda = sp500_hc.sort_values(by = "Ebitda", ascending=False) 
sp500_hc_top_5_ebitda = sp500_hc_top_ebitda.head(5)

# %%
sp500_hc_top_5_ebitda
# Out:
#    Exchange Symbol                        Shortname  \
# 21      NYQ    PFE                     Pfizer, Inc.
# 9       NYQ    JNJ                Johnson & Johnson
# 19      NYQ   ABBV                      AbbVie Inc.
# 7       NYQ    UNH  UnitedHealth Group Incorporated
# 17      NYQ    MRK            Merck & Company, Inc.
#
#                            Longname      Sector                    Industry  \
# 21                      Pfizer Inc.  Healthcare  Drug Manufacturers—General
# 9                 Johnson & Johnson  Healthcare  Drug Manufacturers—General
# 19                      AbbVie Inc.  Healthcare  Drug Manufacturers—General
# 7   UnitedHealth Group Incorporated  Healthcare            Healthcare Plans
# 17                Merck & Co., Inc.  Healthcare  Drug Manufacturers—General
#
#     Currentprice     Marketcap        Ebitda  Revenuegrowth           City  \
# 21         45.11  253196582912  4.352100e+10          0.468       New York
# ...

# %%
sp500_hc_bottom_ebitda = sp500_hc.sort_values(by = "Ebitda", ascending=True) 
sp500_hc_bottom_5_ebitda = sp500_hc_bottom_ebitda.head(5)

# %%
sp500_hc_bottom_5_ebitda
# Out:
#     Exchange Symbol                   Shortname                    Longname  \
# 424      NMS   TECH             Bio-Techne Corp      Bio-Techne Corporation
# 189      NMS   DXCM                DexCom, Inc.                DexCom, Inc.
# 415      NYQ    BIO  Bio-Rad Laboratories, Inc.  Bio-Rad Laboratories, Inc.
# 341      NMS   INCY          Incyte Corporation          Incyte Corporation
# 481      NMS   XRAY        DENTSPLY SIRONA Inc.        DENTSPLY SIRONA Inc.
#
#          Sector                        Industry  Currentprice    Marketcap  \
# 424  Healthcare                   Biotechnology         81.46  12786776064
# 189  Healthcare                 Medical Devices        107.86  41661788160
# 415  Healthcare                 Medical Devices        457.29  13371205632
# 341  Healthcare                   Biotechnology         83.20  18378131456
# 481  Healthcare  Medical Instruments & Supplies         36.97   7945296896
#
# ...

# %%
sp500_hc_top_revenuegrowth = sp500_hc.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_hc_top_5_revenuegrowth = sp500_hc_top_revenuegrowth.head(5)

# %%
sp500_hc_top_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 21       NYQ    PFE                     Pfizer, Inc.
# 341      NMS   INCY               Incyte Corporation
# 17       NYQ    MRK            Merck & Company, Inc.
# 95       NMS   VRTX  Vertex Pharmaceuticals Incorpor
# 317      NYQ    STE             STERIS plc (Ireland)
#
#                                 Longname      Sector  \
# 21                           Pfizer Inc.  Healthcare
# 341                   Incyte Corporation  Healthcare
# 17                     Merck & Co., Inc.  Healthcare
# 95   Vertex Pharmaceuticals Incorporated  Healthcare
# 317                           STERIS plc  Healthcare
#
#                        Industry  Currentprice     Marketcap        Ebitda  \
# 21   Drug Manufacturers—General         45.11  253196582912  4.352100e+10
# 341               Biotechnology         83.20   18378131456  7.972990e+08
# 17   Drug Manufacturers—General        109.94  277701853184  2.348100e+10
# ...

# %%
sp500_hc_bottom_revenuegrowth = sp500_hc.sort_values(by = "Revenuegrowth", ascending=True)
sp500_hc_bottom_5_revenuegrowth = sp500_hc_bottom_revenuegrowth.head(5)

# %%
sp500_hc_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 100      NMS   REGN  Regeneron Pharmaceuticals, Inc.
# 322      NMS   HOLX                    Hologic, Inc.
# 334      NMS   ALGN           Align Technology, Inc.
# 352      NYQ    DGX   Quest Diagnostics Incorporated
# 406      NMS   VTRS                     Viatris Inc.
#
#                             Longname      Sector  \
# 100  Regeneron Pharmaceuticals, Inc.  Healthcare
# 322                    Hologic, Inc.  Healthcare
# 334           Align Technology, Inc.  Healthcare
# 352   Quest Diagnostics Incorporated  Healthcare
# 406                     Viatris Inc.  Healthcare
#
#                                    Industry  Currentprice    Marketcap  \
# 100                           Biotechnology        722.00  77646045184
# 322          Medical Instruments & Supplies         79.66  20028196864
# 334                         Medical Devices        243.01  18982094848
# ...

# %%
# Consumer Cyclical Sector

# %%
sp500_cy = sp500_companies.loc[sp500_companies["Sector"] =="Consumer Cyclical", :]

# %%
sp500_cy_top_marketcap = sp500_cy.sort_values(by = "Marketcap", ascending=False) 
sp500_cy_top_5_marketcap = sp500_cy_top_marketcap.head(5)

# %%
sp500_cy_top_5_marketcap
# Out:
#    Exchange Symbol               Shortname                Longname  \
# 4       NMS   AMZN        Amazon.com, Inc.        Amazon.com, Inc.
# 15      NYQ     HD  Home Depot, Inc. (The)    The Home Depot, Inc.
# 27      NYQ    MCD  McDonald's Corporation  McDonald's Corporation
# 28      NYQ    NKE              Nike, Inc.              NIKE, Inc.
# 53      NYQ    LOW  Lowe's Companies, Inc.  Lowe's Companies, Inc.
#
#                Sector                 Industry  Currentprice     Marketcap  \
# 4   Consumer Cyclical          Internet Retail         97.25  992115359744
# 15  Consumer Cyclical  Home Improvement Retail        315.00  328935604224
# 27  Consumer Cyclical              Restaurants        268.58  200695054336
# 28  Consumer Cyclical   Footwear & Accessories        126.62  200416673792
# 53  Consumer Cyclical  Home Improvement Retail        204.53  137801482240
#
#           Ebitda  Revenuegrowth         City State        Country  \
# ...

# %%
sp500_cy_bottom_marketcap = sp500_cy.sort_values(by = "Marketcap", ascending=True) 
sp500_cy_bottom_5_marketcap = sp500_cy_bottom_marketcap.head(5)

# %%
sp500_cy_bottom_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 490      NYQ   NCLH  Norwegian Cruise Line Holdings
# 483      NYQ    MHK          Mohawk Industries, Inc.
# 479      NYQ    SEE           Sealed Air Corporation
# 472      NMS    HAS                     Hasbro, Inc.
# 470      NYQ    AAP          Advance Auto Parts Inc.
#
#                                 Longname             Sector  \
# 490  Norwegian Cruise Line Holdings Ltd.  Consumer Cyclical
# 483              Mohawk Industries, Inc.  Consumer Cyclical
# 479               Sealed Air Corporation  Consumer Cyclical
# 472                         Hasbro, Inc.  Consumer Cyclical
# 470             Advance Auto Parts, Inc.  Consumer Cyclical
#
#                                Industry  Currentprice   Marketcap  \
# 490                     Travel Services         15.45  6440981504
# 483  Furnishings, Fixtures & Appliances        114.60  7762132992
# 479              Packaging & Containers         53.87  7981216768
# ...

# %%
sp500_cy_top_currentprice = sp500_cy.sort_values(by = "Currentprice", ascending=False) 
sp500_cy_top_5_currentprice = sp500_cy_top_currentprice.head(5)

# %%
sp500_cy_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 360      NYQ    NVR                        NVR, Inc.
# 84       NMS   BKNG  Booking Holdings Inc. Common St
# 176      NYQ    AZO                   AutoZone, Inc.
# 180      NYQ    CMG     Chipotle Mexican Grill, Inc.
# 141      NMS   ORLY        O'Reilly Automotive, Inc.
#
#                          Longname             Sector  \
# 360                     NVR, Inc.  Consumer Cyclical
# 84          Booking Holdings Inc.  Consumer Cyclical
# 176                AutoZone, Inc.  Consumer Cyclical
# 180  Chipotle Mexican Grill, Inc.  Consumer Cyclical
# 141     O'Reilly Automotive, Inc.  Consumer Cyclical
#
#                      Industry  Currentprice    Marketcap        Ebitda  \
# 360  Residential Construction       5024.07  17497579520  2.167959e+09
# 84            Travel Services       2344.29  90933600256  5.073000e+09
# 176          Specialty Retail       2326.61  43660468224  3.691163e+09
# ...

# %%
sp500_cy_bottom_currentprice = sp500_cy.sort_values(by = "Currentprice", ascending=True) 
sp500_cy_bottom_5_currentprice = sp500_cy_bottom_currentprice.head(5)

# %%
sp500_cy_bottom_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 411      NYQ    CCL             Carnival Corporation
# 357      NYQ   AMCR                        Amcor plc
# 150      NYQ      F               Ford Motor Company
# 490      NYQ   NCLH  Norwegian Cruise Line Holdings
# 441      NYQ    VFC                 V.F. Corporation
#
#                                 Longname             Sector  \
# 411           Carnival Corporation & plc  Consumer Cyclical
# 357                            Amcor plc  Consumer Cyclical
# 150                   Ford Motor Company  Consumer Cyclical
# 490  Norwegian Cruise Line Holdings Ltd.  Consumer Cyclical
# 441                     V.F. Corporation  Consumer Cyclical
#
#                    Industry  Currentprice    Marketcap        Ebitda  \
# 411         Travel Services         10.47  13612151808 -1.663001e+09
# 357  Packaging & Containers         11.88  17689559040  2.069000e+09
# 150      Auto Manufacturers         12.40  49553371136  1.745200e+10
# ...

# %%
sp500_cy_top_ebitda = sp500_cy.sort_values(by = "Ebitda", ascending=False) 
sp500_cy_top_5_ebitda = sp500_cy_top_ebitda.head(5)

# %%
sp500_cy_top_5_ebitda
# Out:
#     Exchange Symbol               Shortname                Longname  \
# 4        NMS   AMZN        Amazon.com, Inc.        Amazon.com, Inc.
# 15       NYQ     HD  Home Depot, Inc. (The)    The Home Depot, Inc.
# 150      NYQ      F      Ford Motor Company      Ford Motor Company
# 146      NYQ     GM  General Motors Company  General Motors Company
# 57       NMS   TSLA             Tesla, Inc.             Tesla, Inc.
#
#                 Sector                 Industry  Currentprice     Marketcap  \
# 4    Consumer Cyclical          Internet Retail         97.25  992115359744
# 15   Consumer Cyclical  Home Improvement Retail        315.00  328935604224
# 150  Consumer Cyclical       Auto Manufacturers         12.40   49553371136
# 146  Consumer Cyclical       Auto Manufacturers         35.35   51323248640
# 57   Consumer Cyclical       Auto Manufacturers        133.42  133988360192
#
#            Ebitda  Revenuegrowth      City State        Country  \
# ...

# %%
sp500_cy_bottom_ebitda = sp500_cy.sort_values(by = "Ebitda", ascending=True) 
sp500_cy_bottom_5_ebitda = sp500_cy_bottom_ebitda.head(5)

# %%
sp500_cy_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 382      NYQ    RCL  D/B/A Royal Caribbean Cruises L
# 490      NYQ   NCLH  Norwegian Cruise Line Holdings
# 411      NYQ    CCL             Carnival Corporation
# 188      NYQ    LVS            Las Vegas Sands Corp.
# 442      NMS   WYNN            Wynn Resorts, Limited
#
#                                 Longname             Sector  \
# 382         Royal Caribbean Cruises Ltd.  Consumer Cyclical
# 490  Norwegian Cruise Line Holdings Ltd.  Consumer Cyclical
# 411           Carnival Corporation & plc  Consumer Cyclical
# 188                Las Vegas Sands Corp.  Consumer Cyclical
# 442                Wynn Resorts, Limited  Consumer Cyclical
#
#               Industry  Currentprice    Marketcap        Ebitda  \
# 382    Travel Services         62.99  16049222656 -1.732205e+09
# 490    Travel Services         15.45   6440981504 -1.684442e+09
# 411    Travel Services         10.47  13612151808 -1.663001e+09
# ...

# %%
sp500_cy_top_revenuegrowth = sp500_cy.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_cy_top_5_revenuegrowth = sp500_cy_top_revenuegrowth.head(5)

# %%
sp500_cy_top_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 490      NYQ   NCLH  Norwegian Cruise Line Holdings
# 382      NYQ    RCL  D/B/A Royal Caribbean Cruises L
# 411      NYQ    CCL             Carnival Corporation
# 140      NMS    MAR           Marriott International
# 146      NYQ     GM           General Motors Company
#
#                                 Longname             Sector  \
# 490  Norwegian Cruise Line Holdings Ltd.  Consumer Cyclical
# 382         Royal Caribbean Cruises Ltd.  Consumer Cyclical
# 411           Carnival Corporation & plc  Consumer Cyclical
# 140         Marriott International, Inc.  Consumer Cyclical
# 146               General Motors Company  Consumer Cyclical
#
#                Industry  Currentprice    Marketcap        Ebitda  \
# 490     Travel Services         15.45   6440981504 -1.684442e+09
# 382     Travel Services         62.99  16049222656 -1.732205e+09
# 411     Travel Services         10.47  13612151808 -1.663001e+09
# ...

# %%
sp500_cy_bottom_revenuegrowth = sp500_cy.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_cy_bottom_5_revenuegrowth = sp500_cy_bottom_revenuegrowth.head(5)

# %%
sp500_cy_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol              Shortname               Longname  \
# 455      NYQ    KMX             CarMax Inc           CarMax, Inc.
# 472      NMS    HAS           Hasbro, Inc.           Hasbro, Inc.
# 463      NYQ    WHR  Whirlpool Corporation  Whirlpool Corporation
# 344      NYQ    BBY     Best Buy Co., Inc.     Best Buy Co., Inc.
# 442      NMS   WYNN  Wynn Resorts, Limited  Wynn Resorts, Limited
#
#                 Sector                            Industry  Currentprice  \
# 455  Consumer Cyclical            Auto & Truck Dealerships         66.08
# 472  Consumer Cyclical                             Leisure         63.32
# 463  Consumer Cyclical  Furnishings, Fixtures & Appliances        150.82
# 344  Consumer Cyclical                    Specialty Retail         82.67
# 442  Consumer Cyclical                   Resorts & Casinos         99.27
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# ...

# %%
# Consumer Defensive

# %%
sp500_def = sp500_companies.loc[sp500_companies["Sector"] =="Consumer Defensive", :]

# %%
sp500_def_top_marketcap = sp500_def.sort_values(by = "Marketcap", ascending=False) 
sp500_def_top_5_marketcap = sp500_def_top_marketcap.head(5)

# %%
sp500_def_top_5_marketcap
# Out:
#    Exchange Symbol                       Shortname  \
# 11      NYQ    WMT                    Walmart Inc.
# 14      NYQ     PG  Procter & Gamble Company (The)
# 20      NYQ     KO         Coca-Cola Company (The)
# 23      NMS    PEP                   Pepsico, Inc.
# 26      NMS   COST    Costco Wholesale Corporation
#
#                         Longname              Sector  \
# 11                  Walmart Inc.  Consumer Defensive
# 14  The Procter & Gamble Company  Consumer Defensive
# 20         The Coca-Cola Company  Consumer Defensive
# 23                 PepsiCo, Inc.  Consumer Defensive
# 26  Costco Wholesale Corporation  Consumer Defensive
#
#                          Industry  Currentprice     Marketcap        Ebitda  \
# 11                Discount Stores        140.54  389841092608  3.458600e+10
# 14  Household & Personal Products        142.97  345980272640  2.136400e+10
# 20        Beverages—Non-Alcoholic         60.08  259816587264  1.353100e+10
# ...

# %%
sp500_def_bottom_marketcap = sp500_def.sort_values(by = "Marketcap", ascending=True) 
sp500_def_bottom_5_marketcap = sp500_def_bottom_marketcap.head(5)

# %%
sp500_def_bottom_5_marketcap
# Out:
#     Exchange Symbol                       Shortname  \
# 491      NMS    NWL              Newell Brands Inc.
# 450      NYQ    TAP   Molson Coors Beverage Company
# 405      NYQ     LW      Lamb Weston Holdings, Inc.
# 388      NYQ    CPB           Campbell Soup Company
# 380      NYQ    SJM  J.M. Smucker Company (The) New
#
#                           Longname              Sector  \
# 491             Newell Brands Inc.  Consumer Defensive
# 450  Molson Coors Beverage Company  Consumer Defensive
# 405     Lamb Weston Holdings, Inc.  Consumer Defensive
# 388          Campbell Soup Company  Consumer Defensive
# 380      The J. M. Smucker Company  Consumer Defensive
#
#                           Industry  Currentprice    Marketcap        Ebitda  \
# 491  Household & Personal Products         15.05   6402270208  1.390000e+09
# 450              Beverages—Brewers         49.98  10868001792  1.839000e+09
# 405                 Packaged Foods         96.56  14104326144  7.391000e+08
# ...

# %%
sp500_def_top_currentprice = sp500_def.sort_values(by = "Currentprice", ascending=False) 
sp500_def_top_5_currentprice = sp500_def_top_currentprice.head(5)

# %%
sp500_def_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 26       NMS   COST     Costco Wholesale Corporation
# 77       NYQ     EL  Estee Lauder Companies, Inc. (T
# 145      NYQ     DG       Dollar General Corporation
# 195      NYQ    STZ       Constellation Brands, Inc.
# 174      NYQ    HSY              The Hershey Company
#
#                             Longname              Sector  \
# 26      Costco Wholesale Corporation  Consumer Defensive
# 77   The Estée Lauder Companies Inc.  Consumer Defensive
# 145       Dollar General Corporation  Consumer Defensive
# 195       Constellation Brands, Inc.  Consumer Defensive
# 174              The Hershey Company  Consumer Defensive
#
#                               Industry  Currentprice     Marketcap  \
# 26                     Discount Stores        480.11  213038727168
# 77       Household & Personal Products        267.56   95468617728
# 145                    Discount Stores        230.61   51558633472
# ...

# %%
sp500_def_bottom_currentprice = sp500_def.sort_values(by = "Currentprice", ascending=True) 
sp500_def_bottom_5_currentprice = sp500_def_bottom_currentprice.head(5)

# %%
sp500_def_bottom_5_currentprice
# Out:
#     Exchange Symbol                Shortname                 Longname  \
# 491      NMS    NWL       Newell Brands Inc.       Newell Brands Inc.
# 152      NMS    KDP    Keurig Dr Pepper Inc.    Keurig Dr Pepper Inc.
# 346      NYQ    CAG     ConAgra Brands, Inc.     Conagra Brands, Inc.
# 155      NMS    KHC  The Kraft Heinz Company  The Kraft Heinz Company
# 232      NYQ     KR     Kroger Company (The)           The Kroger Co.
#
#                  Sector                       Industry  Currentprice  \
# 491  Consumer Defensive  Household & Personal Products         15.05
# 152  Consumer Defensive        Beverages—Non-Alcoholic         34.71
# 346  Consumer Defensive                 Packaged Foods         37.98
# 155  Consumer Defensive                 Packaged Foods         39.88
# 232  Consumer Defensive                 Grocery Stores         44.45
#
#        Marketcap        Ebitda  Revenuegrowth        City State  \
# ...

# %%
sp500_def_top_ebitda = sp500_def.sort_values(by = "Ebitda", ascending=False) 
sp500_def_top_5_ebitda = sp500_def_top_ebitda.head(5)

# %%
sp500_def_top_5_ebitda
# Out:
#    Exchange Symbol                        Shortname  \
# 11      NYQ    WMT                     Walmart Inc.
# 14      NYQ     PG   Procter & Gamble Company (The)
# 23      NMS    PEP                    Pepsico, Inc.
# 43      NYQ     PM  Philip Morris International Inc
# 20      NYQ     KO          Coca-Cola Company (The)
#
#                             Longname              Sector  \
# 11                      Walmart Inc.  Consumer Defensive
# 14      The Procter & Gamble Company  Consumer Defensive
# 23                     PepsiCo, Inc.  Consumer Defensive
# 43  Philip Morris International Inc.  Consumer Defensive
# 20             The Coca-Cola Company  Consumer Defensive
#
#                          Industry  Currentprice     Marketcap        Ebitda  \
# 11                Discount Stores        140.54  389841092608  3.458600e+10
# 14  Household & Personal Products        142.97  345980272640  2.136400e+10
# ...

# %%
sp500_def_bottom_ebitda = sp500_def.sort_values(by = "Ebitda", ascending=True) 
sp500_def_bottom_5_ebitda = sp500_def_bottom_ebitda.head(5)

# %%
sp500_def_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 405      NYQ     LW       Lamb Weston Holdings, Inc.
# 358      NYQ    CLX             Clorox Company (The)
# 314      NYQ    MKC  McCormick & Company, Incorporat
# 319      NYQ    CHD    Church & Dwight Company, Inc.
# 239      NYQ   BF-B                 Brown Forman Inc
#
#                               Longname              Sector  \
# 405         Lamb Weston Holdings, Inc.  Consumer Defensive
# 358                 The Clorox Company  Consumer Defensive
# 314  McCormick & Company, Incorporated  Consumer Defensive
# 319          Church & Dwight Co., Inc.  Consumer Defensive
# 239           Brown-Forman Corporation  Consumer Defensive
#
#                               Industry  Currentprice    Marketcap  \
# 405                     Packaged Foods         96.56  14104326144
# 358      Household & Personal Products        142.56  17589766144
# 314                     Packaged Foods         77.44  20703119360
# ...

# %%
sp500_def_top_revenuegrowth = sp500_def.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_def_top_5_revenuegrowth = sp500_def_top_revenuegrowth.head(5)

# %%
sp500_def_top_5_revenuegrowth
# Out:
#     Exchange Symbol                       Shortname  \
# 161      NYQ    ADM  Archer-Daniels-Midland Company
# 174      NYQ    HSY             The Hershey Company
# 199      NYQ    SYY               Sysco Corporation
# 388      NYQ    CPB           Campbell Soup Company
# 405      NYQ     LW      Lamb Weston Holdings, Inc.
#
#                            Longname              Sector           Industry  \
# 161  Archer-Daniels-Midland Company  Consumer Defensive      Farm Products
# 174             The Hershey Company  Consumer Defensive      Confectioners
# 199               Sysco Corporation  Consumer Defensive  Food Distribution
# 388           Campbell Soup Company  Consumer Defensive     Packaged Foods
# 405      Lamb Weston Holdings, Inc.  Consumer Defensive     Packaged Foods
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth     City State  \
# 161         84.75  46556057600  5.277000e+09          0.214  Chicago    IL
# ...

# %%
sp500_def_bottom_revenuegrowth = sp500_def.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_def_bottom_5_revenuegrowth = sp500_def_bottom_revenuegrowth.head(5)

# %%
sp500_def_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 77       NYQ     EL  Estee Lauder Companies, Inc. (T
# 491      NMS    NWL               Newell Brands Inc.
# 358      NYQ    CLX             Clorox Company (The)
# 93       NYQ     MO               Altria Group, Inc.
# 43       NYQ     PM  Philip Morris International Inc
#
#                              Longname              Sector  \
# 77    The Estée Lauder Companies Inc.  Consumer Defensive
# 491                Newell Brands Inc.  Consumer Defensive
# 358                The Clorox Company  Consumer Defensive
# 93                 Altria Group, Inc.  Consumer Defensive
# 43   Philip Morris International Inc.  Consumer Defensive
#
#                           Industry  Currentprice     Marketcap        Ebitda  \
# 77   Household & Personal Products        267.56   95468617728  3.990000e+09
# 491  Household & Personal Products         15.05    6402270208  1.390000e+09
# ...

# %%
# Real Estate

# %%
sp500_rea = sp500_companies.loc[sp500_companies["Sector"] =="Real Estate", :]

# %%
sp500_rea_top_marketcap = sp500_rea.sort_values(by = "Marketcap", ascending=False) 
sp500_rea_top_5_marketcap = sp500_rea_top_marketcap.head(5)

# %%
sp500_rea_top_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 73       NYQ    AMT  American Tower Corporation (REI
# 85       NYQ    PLD                   Prologis, Inc.
# 115      NMS   EQIX                    Equinix, Inc.
# 122      NYQ    CCI                Crown Castle Inc.
# 148      NYQ    PSA                   Public Storage
#
#                        Longname       Sector         Industry  Currentprice  \
# 73   American Tower Corporation  Real Estate   REIT—Specialty        221.41
# 85               Prologis, Inc.  Real Estate  REIT—Industrial        122.82
# 115               Equinix, Inc.  Real Estate   REIT—Specialty        720.06
# 122           Crown Castle Inc.  Real Estate   REIT—Specialty        148.12
# 148              Public Storage  Real Estate  REIT—Industrial        289.10
#
#         Marketcap        Ebitda  Revenuegrowth           City State  \
# 73   103089831936  6.350300e+09          0.088         Boston    MA
# ...

# %%
sp500_rea_bottom_marketcap = sp500_rea.sort_values(by = "Marketcap", ascending=True) 
sp500_rea_bottom_5_marketcap = sp500_rea_bottom_marketcap.head(5)

# %%
sp500_rea_bottom_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 475      NYQ    FRT  Federal Realty Investment Trust
# 448      NMS    REG      Regency Centers Corporation
# 446      NYQ    BXP          Boston Properties, Inc.
# 435      NYQ    CPT            Camden Property Trust
# 431      NYQ    UDR                        UDR, Inc.
#
#                             Longname       Sector          Industry  \
# 475  Federal Realty Investment Trust  Real Estate       REIT—Retail
# 448      Regency Centers Corporation  Real Estate       REIT—Retail
# 446          Boston Properties, Inc.  Real Estate       REIT—Office
# 435            Camden Property Trust  Real Estate  REIT—Residential
# 431                        UDR, Inc.  Real Estate  REIT—Residential
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth             City  \
# 475        107.65   8374040064  6.316950e+08          0.152   North Bethesda
# 448         64.35  11017555968  8.391710e+08          0.133     Jacksonville
# ...

# %%
sp500_rea_top_currentprice = sp500_rea.sort_values(by = "Currentprice", ascending=False) 
sp500_rea_top_5_currentprice = sp500_rea_top_currentprice.head(5)

# %%
sp500_rea_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 115      NMS   EQIX                    Equinix, Inc.
# 236      NMS   SBAC   SBA Communications Corporation
# 148      NYQ    PSA                   Public Storage
# 73       NYQ    AMT  American Tower Corporation (REI
# 400      NYQ    ESS       Essex Property Trust, Inc.
#
#                            Longname       Sector          Industry  \
# 115                   Equinix, Inc.  Real Estate    REIT—Specialty
# 236  SBA Communications Corporation  Real Estate    REIT—Specialty
# 148                  Public Storage  Real Estate   REIT—Industrial
# 73       American Tower Corporation  Real Estate    REIT—Specialty
# 400      Essex Property Trust, Inc.  Real Estate  REIT—Residential
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth          City  \
# 115        720.06   66632982528  2.438837e+09          0.075  Redwood City
# 236        296.81   32287289344  1.588640e+09          0.133    Boca Raton
# ...

# %%
sp500_rea_bottom_currentprice = sp500_rea.sort_values(by = "Currentprice", ascending=True) 
sp500_rea_bottom_5_currentprice = sp500_rea_bottom_currentprice.head(5)

# %%
sp500_rea_bottom_5_currentprice
# Out:
#     Exchange Symbol                      Shortname  \
# 428      NMS    HST                    Host Hotels
# 418      NYQ    KIM  Kimco Realty Corporation (HC)
# 401      NYQ   PEAK    Healthpeak Properties, Inc.
# 337      NYQ   INVH          Invitation Homes Inc.
# 287      NYQ     WY           Weyerhaeuser Company
#
#                         Longname       Sector                    Industry  \
# 428  Host Hotels & Resorts, Inc.  Real Estate          REIT—Hotel & Motel
# 418     Kimco Realty Corporation  Real Estate                 REIT—Retail
# 401  Healthpeak Properties, Inc.  Real Estate  REIT—Healthcare Facilities
# 337        Invitation Homes Inc.  Real Estate            REIT—Residential
# 287         Weyerhaeuser Company  Real Estate              REIT—Specialty
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth      City State  \
# 428         17.61  12574156800  1.196000e+09          1.052  Bethesda    MD
# ...

# %%
sp500_rea_top_ebitda = sp500_rea.sort_values(by = "Ebitda", ascending=False) 
sp500_rea_top_5_ebitda = sp500_rea_top_ebitda.head(5)

# %%
sp500_rea_top_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 73       NYQ    AMT  American Tower Corporation (REI
# 85       NYQ    PLD                   Prologis, Inc.
# 122      NYQ    CCI                Crown Castle Inc.
# 287      NYQ     WY             Weyerhaeuser Company
# 196      NYQ    SPG       Simon Property Group, Inc.
#
#                        Longname       Sector         Industry  Currentprice  \
# 73   American Tower Corporation  Real Estate   REIT—Specialty        221.41
# 85               Prologis, Inc.  Real Estate  REIT—Industrial        122.82
# 122           Crown Castle Inc.  Real Estate   REIT—Specialty        148.12
# 287        Weyerhaeuser Company  Real Estate   REIT—Specialty         32.03
# 196  Simon Property Group, Inc.  Real Estate      REIT—Retail        123.65
#
#         Marketcap        Ebitda  Revenuegrowth           City State  \
# 73   103089831936  6.350300e+09          0.088         Boston    MA
# ...

# %%
sp500_rea_bottom_ebitda = sp500_rea.sort_values(by = "Ebitda", ascending=True) 
sp500_rea_bottom_5_ebitda = sp500_rea_bottom_ebitda.head(5)

# %%
sp500_rea_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 238      NMS   CSGP               CoStar Group, Inc.
# 475      NYQ    FRT  Federal Realty Investment Trust
# 435      NYQ    CPT            Camden Property Trust
# 448      NMS    REG      Regency Centers Corporation
# 431      NYQ    UDR                        UDR, Inc.
#
#                             Longname       Sector              Industry  \
# 238               CoStar Group, Inc.  Real Estate  Real Estate Services
# 475  Federal Realty Investment Trust  Real Estate           REIT—Retail
# 435            Camden Property Trust  Real Estate      REIT—Residential
# 448      Regency Centers Corporation  Real Estate           REIT—Retail
# 431                        UDR, Inc.  Real Estate      REIT—Residential
#
#      Currentprice    Marketcap       Ebitda  Revenuegrowth             City  \
# 238         78.52  31933296640  611323008.0          0.115       Washington
# ...

# %%
sp500_rea_top_revenuegrowth = sp500_rea.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_rea_top_5_revenuegrowth = sp500_rea_top_revenuegrowth.head(5)

# %%
sp500_rea_top_5_revenuegrowth
# Out:
#     Exchange Symbol                      Shortname  \
# 428      NMS    HST                    Host Hotels
# 311      NYQ   VICI           VICI Properties Inc.
# 208      NYQ      O      Realty Income Corporation
# 418      NYQ    KIM  Kimco Realty Corporation (HC)
# 85       NYQ    PLD                 Prologis, Inc.
#
#                         Longname       Sector            Industry  \
# 428  Host Hotels & Resorts, Inc.  Real Estate  REIT—Hotel & Motel
# 311         VICI Properties Inc.  Real Estate    REIT—Diversified
# 208    Realty Income Corporation  Real Estate         REIT—Retail
# 418     Kimco Realty Corporation  Real Estate         REIT—Retail
# 85                Prologis, Inc.  Real Estate     REIT—Industrial
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth           City  \
# 428         17.61  12574156800  1.196000e+09          1.052       Bethesda
# 311         33.58  21120008192  1.210234e+09          1.000       New York
# ...

# %%
sp500_rea_bottom_revenuegrowth = sp500_rea.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_rea_bottom_5_revenuegrowth = sp500_rea_bottom_revenuegrowth.head(5)

# %%
sp500_rea_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                   Shortname                    Longname  \
# 287      NYQ     WY        Weyerhaeuser Company        Weyerhaeuser Company
# 241      NYQ    DLR  Digital Realty Trust, Inc.  Digital Realty Trust, Inc.
# 196      NYQ    SPG  Simon Property Group, Inc.  Simon Property Group, Inc.
# 115      NMS   EQIX               Equinix, Inc.               Equinix, Inc.
# 122      NYQ    CCI           Crown Castle Inc.           Crown Castle Inc.
#
#           Sector        Industry  Currentprice    Marketcap        Ebitda  \
# 287  Real Estate  REIT—Specialty         32.03  23991910400  4.005000e+09
# 241  Real Estate  REIT—Specialty        106.74  31362025472  2.153482e+09
# 196  Real Estate     REIT—Retail        123.65  40633741312  3.706455e+09
# 115  Real Estate  REIT—Specialty        720.06  66632982528  2.438837e+09
# 122  Real Estate  REIT—Specialty        148.12  64143069184  4.012000e+09
#
# ...

# %%
# Utilities

# %%
sp500_util = sp500_companies.loc[sp500_companies["Sector"] =="Utilities", :]

# %%
sp500_util_top_marketcap = sp500_util.sort_values(by = "Marketcap", ascending=False) 
sp500_util_top_5_marketcap = sp500_util_top_marketcap.head(5)

# %%
sp500_util_top_5_marketcap
# Out:
#     Exchange Symbol                        Shortname                 Longname  \
# 41       NYQ    NEE             NextEra Energy, Inc.     NextEra Energy, Inc.
# 97       NYQ    DUK  Duke Energy Corporation (Holdin  Duke Energy Corporation
# 105      NYQ     SO           Southern Company (The)     The Southern Company
# 144      NYQ      D            Dominion Energy, Inc.    Dominion Energy, Inc.
# 149      NYQ    SRE                       DBA Sempra                   Sempra
#
#         Sector                      Industry  Currentprice     Marketcap  \
# 41   Utilities  Utilities—Regulated Electric         81.82  160542294016
# 97   Utilities  Utilities—Regulated Electric        101.82   78407811072
# 105  Utilities  Utilities—Regulated Electric         67.12   71133782016
# 144  Utilities  Utilities—Regulated Electric         62.42   52013023232
# 149  Utilities         Utilities—Diversified        157.99   50452054016
#
# ...

# %%
sp500_util_bottom_marketcap = sp500_util.sort_values(by = "Marketcap", ascending=True) 
sp500_util_bottom_5_marketcap = sp500_util_bottom_marketcap.head(5)

# %%
sp500_util_bottom_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 482      NYQ    NRG                 NRG Energy, Inc.
# 474      NYQ    PNW  Pinnacle West Capital Corporati
# 453      NYQ     NI                     NiSource Inc
# 413      NMS    LNT       Alliant Energy Corporation
# 410      NMS   EVRG                     Evergy, Inc.
#
#                               Longname     Sector  \
# 482                   NRG Energy, Inc.  Utilities
# 474  Pinnacle West Capital Corporation  Utilities
# 453                      NiSource Inc.  Utilities
# 413         Alliant Energy Corporation  Utilities
# 410                       Evergy, Inc.  Utilities
#
#                                   Industry  Currentprice    Marketcap  \
# 482  Utilities—Independent Power Producers         32.21   7886264320
# 474           Utilities—Regulated Electric         75.36   8502040064
# 453                Utilities—Regulated Gas         27.21  10685502464
# ...

# %%
sp500_util_top_currentprice = sp500_util.sort_values(by = "Currentprice", ascending=False) 
sp500_util_top_5_currentprice = sp500_util_top_currentprice.head(5)

# %%
sp500_util_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 149      NYQ    SRE                       DBA Sempra
# 266      NYQ    AWK  American Water Works Company, I
# 304      NYQ    DTE               DTE Energy Company
# 385      NYQ    ATO         Atmos Energy Corporation
# 299      NYQ    ETR              Entergy Corporation
#
#                                Longname     Sector  \
# 149                              Sempra  Utilities
# 266  American Water Works Company, Inc.  Utilities
# 304                  DTE Energy Company  Utilities
# 385            Atmos Energy Corporation  Utilities
# 299                 Entergy Corporation  Utilities
#
#                          Industry  Currentprice    Marketcap        Ebitda  \
# 149         Utilities—Diversified        157.99  50452054016  4.923000e+09
# 266     Utilities—Regulated Water        151.54  27554213888  1.954000e+09
# 304  Utilities—Regulated Electric        113.97  22080776192  2.662000e+09
# ...

# %%
sp500_util_bottom_currentprice = sp500_util.sort_values(by = "Currentprice", ascending=True) 
sp500_util_bottom_5_currentprice = sp500_util_bottom_currentprice.head(5)

# %%
sp500_util_bottom_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 220      NYQ    PCG       Pacific Gas & Electric Co.
# 348      NYQ    AES              The AES Corporation
# 453      NYQ     NI                     NiSource Inc
# 305      NYQ    PPL                  PPL Corporation
# 335      NYQ    CNP  CenterPoint Energy, Inc (Holdin
#
#                      Longname     Sector                      Industry  \
# 220          PG&E Corporation  Utilities  Utilities—Regulated Electric
# 348       The AES Corporation  Utilities         Utilities—Diversified
# 453             NiSource Inc.  Utilities       Utilities—Regulated Gas
# 305           PPL Corporation  Utilities  Utilities—Regulated Electric
# 335  CenterPoint Energy, Inc.  Utilities  Utilities—Regulated Electric
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth           City  \
# 220         15.65  35208429568           NaN            NaN  San Francisco
# ...

# %%
sp500_util_top_ebitda = sp500_util.sort_values(by = "Ebitda", ascending=False) 
sp500_util_top_5_ebitda = sp500_util_top_ebitda.head(5)

# %%
sp500_util_top_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 97       NYQ    DUK  Duke Energy Corporation (Holdin
# 105      NYQ     SO           Southern Company (The)
# 144      NYQ      D            Dominion Energy, Inc.
# 157      NMS    AEP  American Electric Power Company
# 41       NYQ    NEE             NextEra Energy, Inc.
#
#                                   Longname     Sector  \
# 97                 Duke Energy Corporation  Utilities
# 105                   The Southern Company  Utilities
# 144                  Dominion Energy, Inc.  Utilities
# 157  American Electric Power Company, Inc.  Utilities
# 41                    NextEra Energy, Inc.  Utilities
#
#                          Industry  Currentprice     Marketcap        Ebitda  \
# 97   Utilities—Regulated Electric        101.82   78407811072  1.199700e+10
# 105  Utilities—Regulated Electric         67.12   71133782016  8.899000e+09
# 144  Utilities—Regulated Electric         62.42   52013023232  7.295000e+09
# ...

# %%
sp500_util_bottom_ebitda = sp500_util.sort_values(by = "Ebitda", ascending=True) 
sp500_util_bottom_5_ebitda = sp500_util_bottom_ebitda.head(5)

# %%
sp500_util_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 385      NYQ    ATO         Atmos Energy Corporation
# 413      NMS    LNT       Alliant Energy Corporation
# 474      NYQ    PNW  Pinnacle West Capital Corporati
# 453      NYQ     NI                     NiSource Inc
# 269      NMS    CEG  Constellation Energy Corporatio
#
#                               Longname     Sector  \
# 385           Atmos Energy Corporation  Utilities
# 413         Alliant Energy Corporation  Utilities
# 474  Pinnacle West Capital Corporation  Utilities
# 453                      NiSource Inc.  Utilities
# 269   Constellation Energy Corporation  Utilities
#
#                          Industry  Currentprice    Marketcap        Ebitda  \
# 385       Utilities—Regulated Gas        113.00  15934808064  1.464974e+09
# 413  Utilities—Regulated Electric         53.89  13527575552  1.556000e+09
# 474  Utilities—Regulated Electric         75.36   8502040064  1.636350e+09
# ...

# %%
sp500_util_top_revenuegrowth = sp500_util.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_util_top_5_revenuegrowth = sp500_util_top_revenuegrowth.head(5)

# %%
sp500_util_top_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 304      NYQ    DTE               DTE Energy Company
# 482      NYQ    NRG                 NRG Energy, Inc.
# 105      NYQ     SO           Southern Company (The)
# 144      NYQ      D            Dominion Energy, Inc.
# 269      NMS    CEG  Constellation Energy Corporatio
#
#                              Longname     Sector  \
# 304                DTE Energy Company  Utilities
# 482                  NRG Energy, Inc.  Utilities
# 105              The Southern Company  Utilities
# 144             Dominion Energy, Inc.  Utilities
# 269  Constellation Energy Corporation  Utilities
#
#                                   Industry  Currentprice    Marketcap  \
# 304           Utilities—Regulated Electric        113.97  22080776192
# 482  Utilities—Independent Power Producers         32.21   7886264320
# 105           Utilities—Regulated Electric         67.12  71133782016
# ...

# %%
sp500_util_bottom_revenuegrowth = sp500_util.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_util_bottom_5_revenuegrowth = sp500_util_bottom_revenuegrowth.head(5)

# %%
sp500_util_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 278      NYQ    EIX             Edison International
# 266      NYQ    AWK  American Water Works Company, I
# 187      NMS    EXC               Exelon Corporation
# 474      NYQ    PNW  Pinnacle West Capital Corporati
# 335      NYQ    CNP  CenterPoint Energy, Inc (Holdin
#
#                                Longname     Sector  \
# 278                Edison International  Utilities
# 266  American Water Works Company, Inc.  Utilities
# 187                  Exelon Corporation  Utilities
# 474   Pinnacle West Capital Corporation  Utilities
# 335            CenterPoint Energy, Inc.  Utilities
#
#                          Industry  Currentprice    Marketcap        Ebitda  \
# 278  Utilities—Regulated Electric         66.73  25482520576  5.298000e+09
# 266     Utilities—Regulated Water        151.54  27554213888  1.954000e+09
# 187  Utilities—Regulated Electric         42.34  42075037696  6.318000e+09
# ...

# %%
# Energy

# %%
sp500_nrg = sp500_companies.loc[sp500_companies["Sector"] =="Energy", :]

# %%
sp500_nrg_top_marketcap = sp500_nrg.sort_values(by = "Marketcap", ascending=False) 
sp500_nrg_top_5_marketcap = sp500_nrg_top_marketcap.head(5)

# %%
sp500_nrg_top_5_marketcap
# Out:
#    Exchange Symbol                Shortname                 Longname  Sector  \
# 6       NYQ    XOM  Exxon Mobil Corporation  Exxon Mobil Corporation  Energy
# 13      NYQ    CVX      Chevron Corporation      Chevron Corporation  Energy
# 46      NYQ    COP           ConocoPhillips           ConocoPhillips  Energy
# 94      NYQ    SLB        Schlumberger N.V.     Schlumberger Limited  Energy
# 98      NYQ    EOG      EOG Resources, Inc.      EOG Resources, Inc.  Energy
#
#                           Industry  Currentprice     Marketcap        Ebitda  \
# 6             Oil & Gas Integrated        113.35  482948055040  6.970800e+10
# 13            Oil & Gas Integrated        180.90  349795450880  5.292900e+10
# 46                   Oil & Gas E&P        121.80  151771332608  3.428800e+10
# 94  Oil & Gas Equipment & Services         57.35   80440827904  5.407000e+09
# 98                   Oil & Gas E&P        132.75   77976027136  1.357600e+10
#
# ...

# %%
sp500_nrg_bottom_marketcap = sp500_nrg.sort_values(by = "Marketcap", ascending=True) 
sp500_nrg_bottom_5_marketcap = sp500_nrg_bottom_marketcap.head(5)

# %%
sp500_nrg_bottom_5_marketcap
# Out:
#     Exchange Symbol                 Shortname                  Longname  \
# 429      NYQ    EQT           EQT Corporation           EQT Corporation
# 399      NMS    APA           APA Corporation           APA Corporation
# 366      NYQ   TRGP     Targa Resources, Inc.     Targa Resources Corp.
# 321      NYQ   CTRA       Coterra Energy Inc.       Coterra Energy Inc.
# 307      NYQ    MRO  Marathon Oil Corporation  Marathon Oil Corporation
#
#      Sector             Industry  Currentprice    Marketcap        Ebitda  \
# 429  Energy        Oil & Gas E&P         33.95  12461212672  5.284966e+09
# 399  Energy        Oil & Gas E&P         45.09  14496975872  6.414000e+09
# 366  Energy  Oil & Gas Midstream         75.66  17324021760  2.413000e+09
# 321  Energy        Oil & Gas E&P         25.62  20200525824  6.879000e+09
# 307  Energy        Oil & Gas E&P         27.88  21705611264  4.760000e+09
#
#      Revenuegrowth        City State        Country  Fulltimeemployees  \
# ...

# %%
sp500_nrg_top_currentprice = sp500_nrg.sort_values(by = "Currentprice", ascending=False) 
sp500_nrg_top_5_currentprice = sp500_nrg_top_currentprice.head(5)

# %%
sp500_nrg_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 136      NYQ    PXD  Pioneer Natural Resources Compa
# 13       NYQ    CVX              Chevron Corporation
# 156      NYQ    HES                 Hess Corporation
# 272      NMS   FANG         Diamondback Energy, Inc.
# 137      NYQ    VLO        Valero Energy Corporation
#
#                               Longname  Sector  \
# 136  Pioneer Natural Resources Company  Energy
# 13                 Chevron Corporation  Energy
# 156                   Hess Corporation  Energy
# 272           Diamondback Energy, Inc.  Energy
# 137          Valero Energy Corporation  Energy
#
#                            Industry  Currentprice     Marketcap        Ebitda  \
# 136                   Oil & Gas E&P        239.40   58445676544  1.164800e+10
# 13             Oil & Gas Integrated        180.90  349795450880  5.292900e+10
# 156                   Oil & Gas E&P        154.80   47945740288  5.226000e+09
# ...

# %%
sp500_nrg_bottom_currentprice = sp500_nrg.sort_values(by = "Currentprice", ascending=True) 
sp500_nrg_bottom_5_currentprice = sp500_nrg_bottom_currentprice.head(5)

# %%
sp500_nrg_bottom_5_currentprice
# Out:
#     Exchange Symbol                       Shortname  \
# 185      NYQ    KMI             Kinder Morgan, Inc.
# 321      NYQ   CTRA             Coterra Energy Inc.
# 307      NYQ    MRO        Marathon Oil Corporation
# 242      NMS    BKR            Baker Hughes Company
# 206      NYQ    WMB  Williams Companies, Inc. (The)
#
#                          Longname  Sector                        Industry  \
# 185           Kinder Morgan, Inc.  Energy             Oil & Gas Midstream
# 321           Coterra Energy Inc.  Energy                   Oil & Gas E&P
# 307      Marathon Oil Corporation  Energy                   Oil & Gas E&P
# 242          Baker Hughes Company  Energy  Oil & Gas Equipment & Services
# 206  The Williams Companies, Inc.  Energy             Oil & Gas Midstream
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth     City State  \
# 185         18.64  42264891392  6.028000e+09          0.354  Houston    TX
# ...

# %%
sp500_nrg_top_ebitda = sp500_nrg.sort_values(by = "Ebitda", ascending=False) 
sp500_nrg_top_5_ebitda = sp500_nrg_top_ebitda.head(5)

# %%
sp500_nrg_top_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 6        NYQ    XOM          Exxon Mobil Corporation
# 13       NYQ    CVX              Chevron Corporation
# 46       NYQ    COP                   ConocoPhillips
# 129      NYQ    OXY  Occidental Petroleum Corporatio
# 102      NYQ    MPC   Marathon Petroleum Corporation
#
#                              Longname  Sector                        Industry  \
# 6             Exxon Mobil Corporation  Energy            Oil & Gas Integrated
# 13                Chevron Corporation  Energy            Oil & Gas Integrated
# 46                     ConocoPhillips  Energy                   Oil & Gas E&P
# 129  Occidental Petroleum Corporation  Energy                   Oil & Gas E&P
# 102    Marathon Petroleum Corporation  Energy  Oil & Gas Refining & Marketing
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth       City State  \
# 6          113.35  482948055040  6.970800e+10          0.689     Irving    TX
# ...

# %%
sp500_nrg_bottom_ebitda = sp500_nrg.sort_values(by = "Ebitda", ascending=True) 
sp500_nrg_bottom_5_ebitda = sp500_nrg_bottom_ebitda.head(5)

# %%
sp500_nrg_bottom_5_ebitda
# Out:
#     Exchange Symbol                       Shortname  \
# 366      NYQ   TRGP           Targa Resources, Inc.
# 242      NMS    BKR            Baker Hughes Company
# 245      NYQ    OKE                     ONEOK, Inc.
# 215      NYQ    HAL             Halliburton Company
# 206      NYQ    WMB  Williams Companies, Inc. (The)
#
#                          Longname  Sector                        Industry  \
# 366         Targa Resources Corp.  Energy             Oil & Gas Midstream
# 242          Baker Hughes Company  Energy  Oil & Gas Equipment & Services
# 245                   ONEOK, Inc.  Energy             Oil & Gas Midstream
# 215           Halliburton Company  Energy  Oil & Gas Equipment & Services
# 206  The Williams Companies, Inc.  Energy             Oil & Gas Midstream
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth     City State  \
# 366         75.66  17324021760  2.413000e+09          0.773  Houston    TX
# ...

# %%
sp500_nrg_top_revenuegrowth = sp500_nrg.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_nrg_top_5_revenuegrowth = sp500_nrg_top_revenuegrowth.head(5)

# %%
sp500_nrg_top_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 321      NYQ   CTRA              Coterra Energy Inc.
# 46       NYQ    COP                   ConocoPhillips
# 102      NYQ    MPC   Marathon Petroleum Corporation
# 158      NYQ    PSX                      Phillips 66
# 129      NYQ    OXY  Occidental Petroleum Corporatio
#
#                              Longname  Sector                        Industry  \
# 321               Coterra Energy Inc.  Energy                   Oil & Gas E&P
# 46                     ConocoPhillips  Energy                   Oil & Gas E&P
# 102    Marathon Petroleum Corporation  Energy  Oil & Gas Refining & Marketing
# 158                       Phillips 66  Energy  Oil & Gas Refining & Marketing
# 129  Occidental Petroleum Corporation  Energy                   Oil & Gas E&P
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth     City State  \
# 321         25.62   20200525824  6.879000e+09          3.053  Houston    TX
# ...

# %%
sp500_nrg_bottom_revenuegrowth = sp500_nrg.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_nrg_bottom_5_revenuegrowth = sp500_nrg_bottom_revenuegrowth.head(5)

# %%
sp500_nrg_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                       Shortname  \
# 242      NMS    BKR            Baker Hughes Company
# 206      NYQ    WMB  Williams Companies, Inc. (The)
# 94       NYQ    SLB               Schlumberger N.V.
# 184      NYQ    DVN        Devon Energy Corporation
# 272      NMS   FANG        Diamondback Energy, Inc.
#
#                          Longname  Sector                        Industry  \
# 242          Baker Hughes Company  Energy  Oil & Gas Equipment & Services
# 206  The Williams Companies, Inc.  Energy             Oil & Gas Midstream
# 94           Schlumberger Limited  Energy  Oil & Gas Equipment & Services
# 184      Devon Energy Corporation  Energy                   Oil & Gas E&P
# 272      Diamondback Energy, Inc.  Energy                   Oil & Gas E&P
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth           City  \
# 242         31.07  31333163008  2.757000e+09          0.054        Houston
# ...

# %%
# Communication Services

# %%
sp500_comserv = sp500_companies.loc[sp500_companies["Sector"] =="Communication Services", :]

# %%
sp500_comserv_top_marketcap = sp500_comserv.sort_values(by = "Marketcap", ascending=False) 
sp500_comserv_top_5_marketcap = sp500_comserv_top_marketcap.head(5)

# %%
sp500_comserv_top_5_marketcap
# Out:
#    Exchange Symbol                  Shortname                 Longname  \
# 2       NMS   GOOG              Alphabet Inc.            Alphabet Inc.
# 3       NMS  GOOGL              Alphabet Inc.            Alphabet Inc.
# 32      NYQ    DIS  Walt Disney Company (The)  The Walt Disney Company
# 33      NMS   TMUS          T-Mobile US, Inc.        T-Mobile US, Inc.
# 37      NMS  CMCSA        Comcast Corporation      Comcast Corporation
#
#                     Sector                        Industry  Currentprice  \
# 2   Communication Services  Internet Content & Information         99.28
# 3   Communication Services  Internet Content & Information         98.02
# 32  Communication Services                   Entertainment        103.48
# 33  Communication Services                Telecom Services        145.12
# 37  Communication Services                Telecom Services         39.37
#
#         Marketcap        Ebitda  Revenuegrowth           City State  \
# ...

# %%
sp500_comserv_bottom_marketcap = sp500_comserv.sort_values(by = "Marketcap", ascending=True) 
sp500_comserv_bottom_5_marketcap = sp500_comserv_bottom_marketcap.head(5)

# %%
sp500_comserv_bottom_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 494      NYQ   LUMN         Lumen Technologies, Inc.
# 485      NMS   DISH         DISH Network Corporation
# 443      NMS   NWSA                 News Corporation
# 440      NMS    NWS                 News Corporation
# 433      NMS   TTWO  Take-Two Interactive Software,
#
#                                 Longname                  Sector  \
# 494             Lumen Technologies, Inc.  Communication Services
# 485             DISH Network Corporation  Communication Services
# 443                     News Corporation  Communication Services
# 440                     News Corporation  Communication Services
# 433  Take-Two Interactive Software, Inc.  Communication Services
#
#                            Industry  Currentprice    Marketcap        Ebitda  \
# 494                Telecom Services          5.22   5344705536  7.419000e+09
# 485                Telecom Services         13.90   7376813056  3.074426e+09
# ...

# %%
sp500_comserv_top_currentprice = sp500_comserv.sort_values(by = "Currentprice", ascending=False) 
sp500_comserv_top_5_currentprice = sp500_comserv_top_currentprice.head(5)

# %%
sp500_comserv_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 132      NMS   CHTR     Charter Communications, Inc.
# 47       NMS   NFLX                    Netflix, Inc.
# 33       NMS   TMUS                T-Mobile US, Inc.
# 221      NMS     EA             Electronic Arts Inc.
# 433      NMS   TTWO  Take-Two Interactive Software,
#
#                                 Longname                  Sector  \
# 132         Charter Communications, Inc.  Communication Services
# 47                         Netflix, Inc.  Communication Services
# 33                     T-Mobile US, Inc.  Communication Services
# 221                 Electronic Arts Inc.  Communication Services
# 433  Take-Two Interactive Software, Inc.  Communication Services
#
#                            Industry  Currentprice     Marketcap        Ebitda  \
# 132                Telecom Services        396.11   61663232000  2.142500e+10
# 47                    Entertainment        342.50  151711055872  6.021976e+09
# ...

# %%
sp500_comserv_bottom_currentprice = sp500_comserv.sort_values(by = "Currentprice", ascending=True) 
sp500_comserv_bottom_5_currentprice = sp500_comserv_bottom_currentprice.head(5)

# %%
sp500_comserv_bottom_5_currentprice
# Out:
#     Exchange Symbol                 Shortname                  Longname  \
# 494      NYQ   LUMN  Lumen Technologies, Inc.  Lumen Technologies, Inc.
# 485      NMS   DISH  DISH Network Corporation  DISH Network Corporation
# 55       NYQ      T                 AT&T Inc.                 AT&T Inc.
# 443      NMS   NWSA          News Corporation          News Corporation
# 440      NMS    NWS          News Corporation          News Corporation
#
#                      Sector          Industry  Currentprice     Marketcap  \
# 494  Communication Services  Telecom Services          5.22    5344705536
# 485  Communication Services  Telecom Services         13.90    7376813056
# 55   Communication Services  Telecom Services         19.23  137052209152
# 443  Communication Services     Entertainment         19.26   11440921600
# 440  Communication Services     Entertainment         19.64   11569334272
#
#            Ebitda  Revenuegrowth       City State        Country  \
# ...

# %%
sp500_comserv_top_ebitda = sp500_comserv.sort_values(by = "Ebitda", ascending=False) 
sp500_comserv_top_5_ebitda = sp500_comserv_top_ebitda.head(5)

# %%
sp500_comserv_top_5_ebitda
# Out:
#    Exchange Symbol                    Shortname                     Longname  \
# 2       NMS   GOOG                Alphabet Inc.                Alphabet Inc.
# 3       NMS  GOOGL                Alphabet Inc.                Alphabet Inc.
# 55      NYQ      T                    AT&T Inc.                    AT&T Inc.
# 39      NYQ     VZ  Verizon Communications Inc.  Verizon Communications Inc.
# 37      NMS  CMCSA          Comcast Corporation          Comcast Corporation
#
#                     Sector                        Industry  Currentprice  \
# 2   Communication Services  Internet Content & Information         99.28
# 3   Communication Services  Internet Content & Information         98.02
# 55  Communication Services                Telecom Services         19.23
# 39  Communication Services                Telecom Services         40.00
# 37  Communication Services                Telecom Services         39.37
#
# ...

# %%
sp500_comserv_bottom_ebitda = sp500_comserv.sort_values(by = "Ebitda", ascending=True) 
sp500_comserv_bottom_5_ebitda = sp500_comserv_bottom_ebitda.head(5)

# %%
sp500_comserv_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 433      NMS   TTWO  Take-Two Interactive Software,
# 373      NYQ    LYV  Live Nation Entertainment, Inc.
# 403      NMS   MTCH                Match Group, Inc.
# 443      NMS   NWSA                 News Corporation
# 440      NMS    NWS                 News Corporation
#
#                                 Longname                  Sector  \
# 433  Take-Two Interactive Software, Inc.  Communication Services
# 373      Live Nation Entertainment, Inc.  Communication Services
# 403                    Match Group, Inc.  Communication Services
# 443                     News Corporation  Communication Services
# 440                     News Corporation  Communication Services
#
#                            Industry  Currentprice    Marketcap        Ebitda  \
# 433  Electronic Gaming & Multimedia        106.59  12289826816  7.524680e+08
# 373                   Entertainment         75.11  16874212352  7.734870e+08
# ...

# %%
sp500_comserv_top_revenuegrowth = sp500_comserv.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_comserv_top_5_revenuegrowth = sp500_comserv_top_revenuegrowth.head(5)

# %%
sp500_comserv_top_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 373      NYQ    LYV  Live Nation Entertainment, Inc.
# 433      NMS   TTWO  Take-Two Interactive Software,
# 403      NMS   MTCH                Match Group, Inc.
# 32       NYQ    DIS        Walt Disney Company (The)
# 443      NMS   NWSA                 News Corporation
#
#                                 Longname                  Sector  \
# 373      Live Nation Entertainment, Inc.  Communication Services
# 433  Take-Two Interactive Software, Inc.  Communication Services
# 403                    Match Group, Inc.  Communication Services
# 32               The Walt Disney Company  Communication Services
# 443                     News Corporation  Communication Services
#
#                            Industry  Currentprice     Marketcap        Ebitda  \
# 373                   Entertainment         75.11   16874212352  7.734870e+08
# 433  Electronic Gaming & Multimedia        106.59   12289826816  7.524680e+08
# ...

# %%
sp500_comserv_bottom_revenuegrowth = sp500_comserv.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_comserv_bottom_5_revenuegrowth = sp500_comserv_bottom_revenuegrowth.head(5)

# %%
sp500_comserv_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                 Shortname                   Longname  \
# 138      NMS   ATVI  Activision Blizzard, Inc  Activision Blizzard, Inc.
# 485      NMS   DISH  DISH Network Corporation   DISH Network Corporation
# 494      NYQ   LUMN  Lumen Technologies, Inc.   Lumen Technologies, Inc.
# 55       NYQ      T                 AT&T Inc.                  AT&T Inc.
# 37       NMS  CMCSA       Comcast Corporation        Comcast Corporation
#
#                      Sector                        Industry  Currentprice  \
# 138  Communication Services  Electronic Gaming & Multimedia         73.84
# 485  Communication Services                Telecom Services         13.90
# 494  Communication Services                Telecom Services          5.22
# 55   Communication Services                Telecom Services         19.23
# 37   Communication Services                Telecom Services         39.37
#
#         Marketcap        Ebitda  Revenuegrowth          City State  \
# ...

# %%
# Basic Materials

# %%
sp500_bam = sp500_companies.loc[sp500_companies["Sector"] =="Basic Materials", :]

# %%
sp500_bam_top_marketcap = sp500_bam.sort_values(by = "Marketcap", ascending=False) 
sp500_bam_top_5_marketcap = sp500_bam_top_marketcap.head(5)

# %%
sp500_bam_top_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 38       NYQ    LIN                        Linde plc
# 110      NYQ    APD  Air Products and Chemicals, Inc
# 114      NYQ    FCX           Freeport-McMoRan, Inc.
# 121      NYQ    SHW   Sherwin-Williams Company (The)
# 171      NYQ   CTVA                    Corteva, Inc.
#
#                              Longname           Sector             Industry  \
# 38                          Linde plc  Basic Materials  Specialty Chemicals
# 110  Air Products and Chemicals, Inc.  Basic Materials  Specialty Chemicals
# 114             Freeport-McMoRan Inc.  Basic Materials               Copper
# 121      The Sherwin-Williams Company  Basic Materials  Specialty Chemicals
# 171                     Corteva, Inc.  Basic Materials  Agricultural Inputs
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth          City  \
# 38         328.62  168435826688  1.055200e+10          0.115        Woking
# ...

# %%
sp500_bam_bottom_marketcap = sp500_bam.sort_values(by = "Marketcap", ascending=True) 
sp500_bam_bottom_5_marketcap = sp500_bam_bottom_marketcap.head(5)

# %%
sp500_bam_bottom_5_marketcap
# Out:
#     Exchange Symbol                        Shortname  \
# 451      NYQ    EMN         Eastman Chemical Company
# 420      NYQ     CE  Celanese Corporation Celanese C
# 377      NYQ    FMC                  FMC Corporation
# 371      NYQ     CF     CF Industries Holdings, Inc.
# 354      NYQ    MOS             Mosaic Company (The)
#
#                          Longname           Sector             Industry  \
# 451      Eastman Chemical Company  Basic Materials  Specialty Chemicals
# 420          Celanese Corporation  Basic Materials            Chemicals
# 377               FMC Corporation  Basic Materials  Agricultural Inputs
# 371  CF Industries Holdings, Inc.  Basic Materials  Agricultural Inputs
# 354            The Mosaic Company  Basic Materials  Agricultural Inputs
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth          City  \
# 451         89.82  10777501696  2.217000e+09         -0.004     Kingsport
# ...

# %%
sp500_bam_top_currentprice = sp500_bam.sort_values(by = "Currentprice", ascending=False) 
sp500_bam_top_5_currentprice = sp500_bam_top_currentprice.head(5)

# %%
sp500_bam_top_5_currentprice
# Out:
#     Exchange Symbol                        Shortname  \
# 308      NYQ    MLM  Martin Marietta Materials, Inc.
# 38       NYQ    LIN                        Linde plc
# 110      NYQ    APD  Air Products and Chemicals, Inc
# 257      NYQ    ALB            Albemarle Corporation
# 121      NYQ    SHW   Sherwin-Williams Company (The)
#
#                              Longname           Sector             Industry  \
# 308   Martin Marietta Materials, Inc.  Basic Materials   Building Materials
# 38                          Linde plc  Basic Materials  Specialty Chemicals
# 110  Air Products and Chemicals, Inc.  Basic Materials  Specialty Chemicals
# 257             Albemarle Corporation  Basic Materials  Specialty Chemicals
# 121      The Sherwin-Williams Company  Basic Materials  Specialty Chemicals
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth       City State  \
# 308        347.69   21689563136  1.522400e+09          0.176    Raleigh    NC
# ...

# %%
sp500_bam_bottom_currentprice = sp500_bam.sort_values(by = "Currentprice", ascending=True) 
sp500_bam_bottom_5_currentprice = sp500_bam_bottom_currentprice.head(5)

# %%
sp500_bam_bottom_5_currentprice
# Out:
#     Exchange Symbol               Shortname               Longname  \
# 114      NYQ    FCX  Freeport-McMoRan, Inc.  Freeport-McMoRan Inc.
# 354      NYQ    MOS    Mosaic Company (The)     The Mosaic Company
# 183      NYQ    NEM     Newmont Corporation    Newmont Corporation
# 197      NYQ    DOW                Dow Inc.               Dow Inc.
# 171      NYQ   CTVA           Corteva, Inc.          Corteva, Inc.
#
#               Sector             Industry  Currentprice    Marketcap  \
# 114  Basic Materials               Copper         45.41  66683224064
# 354  Basic Materials  Agricultural Inputs         48.01  17783382016
# 183  Basic Materials                 Gold         53.34  42535182336
# 197  Basic Materials            Chemicals         57.44  40423915520
# 171  Basic Materials  Agricultural Inputs         62.36  44555722752
#
#            Ebitda  Revenuegrowth          City State        Country  \
# 114  1.001400e+10         -0.178       Phoenix    AZ  United States
# ...

# %%
sp500_bam_top_ebitda = sp500_bam.sort_values(by = "Ebitda", ascending=False) 
sp500_bam_top_5_ebitda = sp500_bam_top_ebitda.head(5)

# %%
sp500_bam_top_5_ebitda
# Out:
#     Exchange Symbol                     Shortname  \
# 175      NYQ    NUE             Nucor Corporation
# 38       NYQ    LIN                     Linde plc
# 114      NYQ    FCX        Freeport-McMoRan, Inc.
# 197      NYQ    DOW                      Dow Inc.
# 248      NYQ    LYB  LyondellBasell Industries NV
#
#                            Longname           Sector             Industry  \
# 175               Nucor Corporation  Basic Materials                Steel
# 38                        Linde plc  Basic Materials  Specialty Chemicals
# 114           Freeport-McMoRan Inc.  Basic Materials               Copper
# 197                        Dow Inc.  Basic Materials            Chemicals
# 248  LyondellBasell Industries N.V.  Basic Materials  Specialty Chemicals
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth       City State  \
# 175        153.47   43861573632  1.286827e+10          0.018  Charlotte    NC
# ...

# %%
sp500_bam_bottom_ebitda = sp500_bam.sort_values(by = "Ebitda", ascending=True) 
sp500_bam_bottom_5_ebitda = sp500_bam_bottom_ebitda.head(5)

# %%
sp500_bam_bottom_5_ebitda
# Out:
#     Exchange Symbol                        Shortname  \
# 377      NYQ    FMC                  FMC Corporation
# 290      NYQ    VMC  Vulcan Materials Company (Holdi
# 308      NYQ    MLM  Martin Marietta Materials, Inc.
# 257      NYQ    ALB            Albemarle Corporation
# 244      NYQ    PPG             PPG Industries, Inc.
#
#                             Longname           Sector             Industry  \
# 377                  FMC Corporation  Basic Materials  Agricultural Inputs
# 290         Vulcan Materials Company  Basic Materials   Building Materials
# 308  Martin Marietta Materials, Inc.  Basic Materials   Building Materials
# 257            Albemarle Corporation  Basic Materials  Specialty Chemicals
# 244             PPG Industries, Inc.  Basic Materials  Specialty Chemicals
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth          City  \
# 377        128.20  16249478144  1.384200e+09          0.169  Philadelphia
# ...

# %%
sp500_bam_top_revenuegrowth = sp500_bam.sort_values(by = "Revenuegrowth", ascending=False) 
sp500_bam_top_5_revenuegrowth = sp500_bam_top_revenuegrowth.head(5)

# %%
sp500_bam_top_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 257      NYQ    ALB            Albemarle Corporation
# 354      NYQ    MOS             Mosaic Company (The)
# 371      NYQ     CF     CF Industries Holdings, Inc.
# 290      NYQ    VMC  Vulcan Materials Company (Holdi
# 248      NYQ    LYB     LyondellBasell Industries NV
#
#                            Longname           Sector             Industry  \
# 257           Albemarle Corporation  Basic Materials  Specialty Chemicals
# 354              The Mosaic Company  Basic Materials  Agricultural Inputs
# 371    CF Industries Holdings, Inc.  Basic Materials  Agricultural Inputs
# 290        Vulcan Materials Company  Basic Materials   Building Materials
# 248  LyondellBasell Industries N.V.  Basic Materials  Specialty Chemicals
#
#      Currentprice    Marketcap        Ebitda  Revenuegrowth        City State  \
# 257        248.49  29111349248  2.123138e+09          1.519   Charlotte    NC
# ...

# %%
sp500_bam_bottom_revenuegrowth = sp500_bam.sort_values(by = "Revenuegrowth", ascending=True) 
sp500_bam_bottom_5_revenuegrowth = sp500_bam_bottom_revenuegrowth.head(5)

# %%
sp500_bam_bottom_5_revenuegrowth
# Out:
#     Exchange Symbol                        Shortname  \
# 114      NYQ    FCX           Freeport-McMoRan, Inc.
# 197      NYQ    DOW                         Dow Inc.
# 451      NYQ    EMN         Eastman Chemical Company
# 259      NYQ    IFF  International Flavors & Fragran
# 183      NYQ    NEM              Newmont Corporation
#
#                                     Longname           Sector  \
# 114                    Freeport-McMoRan Inc.  Basic Materials
# 197                                 Dow Inc.  Basic Materials
# 451                 Eastman Chemical Company  Basic Materials
# 259  International Flavors & Fragrances Inc.  Basic Materials
# 183                      Newmont Corporation  Basic Materials
#
#                 Industry  Currentprice    Marketcap        Ebitda  \
# 114               Copper         45.41  66683224064  1.001400e+10
# 197            Chemicals         57.44  40423915520  9.958000e+09
# 451  Specialty Chemicals         89.82  10777501696  2.217000e+09
# ...
